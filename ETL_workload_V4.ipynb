# %%
#API
import requests
from concurrent.futures import ThreadPoolExecutor, as_completed

#ETL
import pandas as pd
from pandas import json_normalize
import time
import json
import numpy as np
from datetime import datetime, timezone
from pathlib import Path

#DB
from sqlalchemy import create_engine, text
from sqlalchemy.exc import SQLAlchemyError

#Other
import os
from dotenv import load_dotenv

# %%
load_dotenv()
api_key = os.getenv('api_key')
db_password = os.getenv('db_password')
db_user = os.getenv('db_user')
db_host = os.getenv('db_host')
db_port = os.getenv('db_port')
db_name = os.getenv('db_name')

# %%
headers = {"Authorization": f"Bearer {api_key}"}

# %%
championship_map = {
    '786da1fa-a9b5-4d17-b40e-416588272db4' : 'Advanced',
    'bd7957b3-1114-435f-af43-22645a508cc0': 'Main',
    '4410aa73-9584-4500-a7ca-1504ed6da707': 'Intermediate',
    'e61be909-1727-4de3-8201-419d89893401':'Entry',
    'f62c4c75-f620-40a2-bef8-0be2cb85d2d3': 'Open10',
    '0ce757ef-9bad-4afa-bbce-58d647824222':'Open9',
    '3cd81a7e-ed93-43ba-be08-2a1ee7ad7237':'Open1-8'
}

# %% [markdown]
# ## Call API pour récupérer les données

# %%
data_dir = r"D:\Data project\Faceit dashboard\FaceitApi_Dataproject\data"
season = "Season 54"
region = "EU"
stage = "Regular"
start_season_unix = 1751328000

# %%
limit = 100
delay = 0.5
max_threads = 5

# %% [markdown]
# ### List Teams and Team_leaders from championship api call

# %%
def fetch_incremental_matches(championship_map, headers,
                              season=season, region=region, stage=stage,
                              data_dir=data_dir, limit=100, delay=0.3):
    base_path = os.path.join(data_dir, season, region, stage)
    os.makedirs(base_path, exist_ok=True)

    # Load existing team_details.json
    team_file = os.path.join(base_path, "team_list.json")
    try:
        with open(team_file, "r") as f:
            team_list = json.load(f)
    except FileNotFoundError:
        team_list = []

    existing_team_ids = {team["team_id"] for team in team_list}

    # Load existing master.json
    master_file = os.path.join(base_path, "master.json")
    try:
        with open(master_file, "r") as f:
            master_matches = json.load(f)
    except FileNotFoundError:
        master_matches = []

    existing_match_ids = {match["match_id"] for match in master_matches}

    parameters = ["upcoming", "past", "all"]

    for champ_id, champ_name in championship_map.items():
        champ_folder = os.path.join(base_path, champ_name)
        os.makedirs(champ_folder, exist_ok=True)
        champ_file = os.path.join(champ_folder, "matches.json")

        # Load existing matches
        try:
            with open(champ_file, "r") as f:
                champ_matches = json.load(f)
        except FileNotFoundError:
            champ_matches = []

        champ_match_ids = {m["match_id"] for m in champ_matches}

        for param in parameters:
            offset = 0
            while True:
                url = f"https://open.faceit.com/data/v4/championships/{champ_id}/matches?region={region}&type={param}&limit={limit}&offset={offset}"
                response = requests.get(url, headers=headers)
                if response.status_code != 200:
                    print(f"Error fetching {champ_name} ({champ_id}) offset {offset} param={param}: {response.status_code}")
                    break

                data = response.json()
                items = data.get("items", [])
                if not items:
                    break

                # Filter new matches
                new_items = [m for m in items if m["match_id"] not in champ_match_ids]
                if new_items:
                    champ_matches.extend(new_items)
                    champ_match_ids.update([m["match_id"] for m in new_items])
                    print(f"Added {len(new_items)} new matches to {champ_file}")

                    # Update master.json
                    for m in new_items:
                        if m["match_id"] not in existing_match_ids:
                            master_matches.append(m)
                            existing_match_ids.add(m["match_id"])

                        # Extract teams and leaders
                        teams = m.get("teams", {})
                        for faction in teams.values():
                            if isinstance(faction, dict):
                                team_id = faction.get("faction_id")
                                if team_id and team_id not in existing_team_ids:
                                    team_info = {
                                        "team_id": team_id,
                                        "name": faction.get("name"),
                                        "avatar": faction.get("avatar"),
                                        "type": faction.get("type"),
                                        "leader_id": faction.get("leader")
                                    }
                                    team_list.append(team_info)
                                    existing_team_ids.add(team_id)

                offset += limit
                time.sleep(delay)

        # Save championship matches
        with open(champ_file, "w") as f:
            json.dump(champ_matches, f, indent=2)

    # Save master.json and team_list.json
    with open(master_file, "w") as f:
        json.dump(master_matches, f, indent=2)

    with open(team_file, "w") as f:
        json.dump(team_list, f, indent=2)

    print(f"Incremental fetch finished. Total matches in master: {len(master_matches)}")
    print(f"Total teams in team_list.json: {len(team_list)}")

    return master_matches, team_list

# -----------------------------
# RUN INCREMENTAL FETCH
# -----------------------------
master_matches, team_list = fetch_incremental_matches(championship_map, headers)
# Out:
# Error fetching Main (bd7957b3-1114-435f-af43-22645a508cc0) offset 600 param=past: 400
# Error fetching Main (bd7957b3-1114-435f-af43-22645a508cc0) offset 600 param=all: 400
# Error fetching Intermediate (4410aa73-9584-4500-a7ca-1504ed6da707) offset 600 param=past: 400
# Error fetching Intermediate (4410aa73-9584-4500-a7ca-1504ed6da707) offset 600 param=all: 400
# Error fetching Entry (e61be909-1727-4de3-8201-419d89893401) offset 600 param=past: 400
# Error fetching Entry (e61be909-1727-4de3-8201-419d89893401) offset 600 param=all: 400
# Error fetching Open10 (f62c4c75-f620-40a2-bef8-0be2cb85d2d3) offset 600 param=past: 400
# Error fetching Open10 (f62c4c75-f620-40a2-bef8-0be2cb85d2d3) offset 600 param=all: 400
# Error fetching Open9 (0ce757ef-9bad-4afa-bbce-58d647824222) offset 600 param=past: 400
# Error fetching Open9 (0ce757ef-9bad-4afa-bbce-58d647824222) offset 600 param=all: 400
# Error fetching Open1-8 (3cd81a7e-ed93-43ba-be08-2a1ee7ad7237) offset 600 param=past: 400
# Error fetching Open1-8 (3cd81a7e-ed93-43ba-be08-2a1ee7ad7237) offset 600 param=all: 400
# Incremental fetch finished. Total matches in master: 6907
# Total teams in team_list.json: 1339

# %% [markdown]
# ### List all recent matches from captains and filter those being ESEA related

# %%
# -----------------------------
# FILE PATHS
# -----------------------------
team_details_file = os.path.join(data_dir, season, region, stage, "team_list.json")
output_file = os.path.join(data_dir, season, region, stage, "all_captain_matches.json")
os.makedirs(os.path.dirname(output_file), exist_ok=True)

# -----------------------------
# HELPER FUNCTION: FETCH ONE CAPTAIN
# -----------------------------
def fetch_captain_matches(player_id, existing_matches, from_timestamp, api_key, limit, delay):
    headers = {"Authorization": f"Bearer {api_key}"}
    match_info = existing_matches.copy()
    offset = 0

    while True:
        url = f"https://open.faceit.com/data/v4/players/{player_id}/history?game=cs2&from={from_timestamp}&limit={limit}&offset={offset}"
        response = requests.get(url, headers=headers)

        if response.status_code != 200:
            print(f"Error for {player_id}: {response.status_code}")
            break

        data = response.json()
        matches = data.get("items", [])

        if not matches:
            break

        new_count = 0
        for match in matches:
            match_id = match["match_id"]
            if match_id not in match_info:
                competition_id = match.get("competition_id")
                started_at = match.get("started_at")
                faction1_team_id = match.get("teams", {}).get("faction1", {}).get("team_id")
                faction2_team_id = match.get("teams", {}).get("faction2", {}).get("team_id")
                winner = match.get("results", {}).get("winner")

                match_info[match_id] = {
                    "competition_id": competition_id,
                    "started_at": started_at,
                    "faction1_team_id": faction1_team_id,
                    "faction2_team_id": faction2_team_id,
                    "winner": winner
                }
                new_count += 1

        print(f"{player_id} offset {offset}: {len(matches)} fetched, {new_count} new matches added")
        offset += limit

        if len(matches) < limit:
            break

        time.sleep(delay)

    return player_id, match_info

# -----------------------------
# MAIN FUNCTION: INCREMENTAL FETCH WITH THREADS
# -----------------------------
def fetch_incremental_captain_matches(captains_ids, api_key, start_season_unix,
                                      filename=output_file, limit=100, delay=0.5, max_threads=5):

    # Load existing data
    if os.path.exists(filename):
        with open(filename, "r") as f:
            all_captain_matches = json.load(f)
        print(f"Loaded existing captain matches from {filename}")
    else:
        all_captain_matches = {}

    # Determine global latest timestamp among all existing captains
    latest_global_timestamp = 0
    for matches in all_captain_matches.values():
        for match in matches.values():
            ts = match.get("started_at", 0)
            if ts > latest_global_timestamp:
                latest_global_timestamp = ts

    print(f"Global latest started_at timestamp: {latest_global_timestamp}")

    # Counter for new matches across all captains
    total_new_matches = 0

    # Prepare tasks
    with ThreadPoolExecutor(max_workers=max_threads) as executor:
        futures = {}
        for player_id in captains_ids:
            existing_matches = all_captain_matches.get(player_id, {})
            if existing_matches:
                from_timestamp = latest_global_timestamp + 1
            else:
                from_timestamp = int(start_season_unix)

            future = executor.submit(
                fetch_captain_matches,
                player_id,
                existing_matches,
                from_timestamp,
                api_key,
                limit,
                delay
            )
            futures[future] = player_id

        # Collect results
        for future in as_completed(futures):
            player_id, match_info = future.result()
            before = len(all_captain_matches.get(player_id, {}))
            after = len(match_info)
            new_for_player = after - before
            total_new_matches += new_for_player

            all_captain_matches[player_id] = match_info
            print(f"{player_id}: {new_for_player} new matches, total now {after}")

    # Save updated JSON
    with open(filename, "w") as f:
        json.dump(all_captain_matches, f, indent=2)

    print(f"✅ All captain matches updated in {filename}")
    print(f"🎯 Total new matches fetched this run: {total_new_matches}")

    return all_captain_matches, total_new_matches

# -----------------------------
# EXECUTION
# -----------------------------
with open(team_details_file, "r") as f:
    teams = json.load(f)

captains_ids = list({team["leader_id"] for team in teams if "leader_id" in team})
print(f"Found {len(captains_ids)} captains to fetch.")

all_captain_matches, total_new_matches = fetch_incremental_captain_matches(
    captains_ids, api_key, start_season_unix, limit=limit, delay=delay, max_threads=max_threads
)
# Out:
# Found 1339 captains to fetch.
# Loaded existing captain matches from D:\Data project\Faceit dashboard\FaceitApi_Dataproject\data\Season 54\EU\Regular\all_captain_matches.json
# Global latest started_at timestamp: 1756101734
# Error for : 404
# : 0 new matches, total now 0
# 5c396e71-66ae-43b6-b9c0-d1f09fe0cfdc: 0 new matches, total now 192
# 61cd4ed7-81c1-45bc-b7a9-b6ea8940128b: 0 new matches, total now 5
# ae8bd4b7-5321-43c5-aa48-c2b3f3a804d6: 0 new matches, total now 73
# 8f180385-bd39-4ea6-89f3-c524b423ea96 offset 0: 5 fetched, 5 new matches added
# 8f180385-bd39-4ea6-89f3-c524b423ea96: 5 new matches, total now 129
# 92fa44f8-f5b0-4b55-988f-96ec564da9bc offset 0: 6 fetched, 6 new matches added
# 92fa44f8-f5b0-4b55-988f-96ec564da9bc: 6 new matches, total now 183
# ab0a0e7f-2951-4206-b046-7939a1636d29 offset 0: 3 fetched, 3 new matches added
# ab0a0e7f-2951-4206-b046-7939a1636d29: 3 new matches, total now 378
# 0f730532-6bd0-4cec-be0b-5d3f949ae342 offset 0: 4 fetched, 4 new matches added
# 0f730532-6bd0-4cec-be0b-5d3f949ae342: 4 new matches, total now 161
# 0a93e60e-0f2c-45d9-b783-df5da7a83541 offset 0: 4 fetched, 4 new matches added
# 0a93e60e-0f2c-45d9-b783-df5da7a83541: 4 new matches, total now 228
# a895c53f-113c-42e1-b76f-0935a91e7231: 0 new matches, total now 100
# 74834f0d-bf5e-4cba-bfe3-2e92b850f939 offset 0: 1 fetched, 1 new matches added
# 03c8298f-d2ee-4904-bc27-075973ae7dee offset 0: 2 fetched, 2 new matches added
# 03c8298f-d2ee-4904-bc27-075973ae7dee: 2 new matches, total now 163
# 74834f0d-bf5e-4cba-bfe3-2e92b850f939: 1 new matches, total now 173
# 52f342fa-5746-4f85-a4e9-d99b51f03a46 offset 0: 5 fetched, 5 new matches added
# 52f342fa-5746-4f85-a4e9-d99b51f03a46: 5 new matches, total now 44
# c51ffbd8-036e-4934-9622-c5afaa41ebba offset 0: 2 fetched, 2 new matches added
# c51ffbd8-036e-4934-9622-c5afaa41ebba: 2 new matches, total now 58
# 3d91af0d-636d-41ef-9538-9d47859015aa: 0 new matches, total now 10
# 1032f57b-e4df-44a9-848c-56a88ca74d5d offset 0: 4 fetched, 4 new matches added
# 1032f57b-e4df-44a9-848c-56a88ca74d5d: 4 new matches, total now 224
# 9cbd4fee-5696-4188-b1ff-524b0ace1bcc: 0 new matches, total now 2
# 726f58cd-24d8-4cd2-81a0-5521d627a8e7 offset 0: 3 fetched, 3 new matches added
# 726f58cd-24d8-4cd2-81a0-5521d627a8e7: 3 new matches, total now 167
# 2499884a-f648-486b-87f6-2868aba3113f offset 0: 3 fetched, 3 new matches added
# 2499884a-f648-486b-87f6-2868aba3113f: 3 new matches, total now 102
# 99d7a350-6f38-4a12-915a-49b423a79302 offset 0: 1 fetched, 1 new matches added
# 99d7a350-6f38-4a12-915a-49b423a79302: 1 new matches, total now 19
# 395715e3-4853-4bac-b3ad-4c9fd520a9cd offset 0: 7 fetched, 7 new matches added
# 395715e3-4853-4bac-b3ad-4c9fd520a9cd: 7 new matches, total now 58
# 72e06938-b0cd-43d3-90d7-7db513dcfa0f: 0 new matches, total now 122
# be678e4a-5152-4b38-81a7-f1ec79914a41: 0 new matches, total now 232
# 8c0f480c-42b5-443c-85bb-4d45fc076150: 0 new matches, total now 46
# 4e5509bf-cd82-404c-afbe-29eba8702568: 0 new matches, total now 72
# dd44cc6d-b628-40b8-b7f6-ec7b45d09940 offset 0: 3 fetched, 3 new matches added
# dd44cc6d-b628-40b8-b7f6-ec7b45d09940: 3 new matches, total now 83
# 4a1820a9-5c5f-42d3-957e-632ca1555940 offset 0: 1 fetched, 1 new matches added
# 4a1820a9-5c5f-42d3-957e-632ca1555940: 1 new matches, total now 84
# 7d7ffa39-e56c-491c-92e3-6d5e4dddbbe6 offset 0: 1 fetched, 1 new matches added
# 7d7ffa39-e56c-491c-92e3-6d5e4dddbbe6: 1 new matches, total now 60
# f16c5f2d-dd28-4d50-8b1d-4956b74e7edb offset 0: 1 fetched, 1 new matches added
# f16c5f2d-dd28-4d50-8b1d-4956b74e7edb: 1 new matches, total now 199
# 1f385e75-f064-440d-a2e6-564f87f0fc73 offset 0: 4 fetched, 4 new matches added
# 1f385e75-f064-440d-a2e6-564f87f0fc73: 4 new matches, total now 76
# 34a35310-09f5-4151-bbc1-f22b716afb6b: 0 new matches, total now 97
# 8de39fa9-4812-4267-8f57-7088b2ccf252 offset 0: 5 fetched, 5 new matches added
# 8de39fa9-4812-4267-8f57-7088b2ccf252: 5 new matches, total now 189
# 12d3a2af-1959-41f1-aa1d-f8d4dde4dddd offset 0: 1 fetched, 1 new matches added
# 12d3a2af-1959-41f1-aa1d-f8d4dde4dddd: 1 new matches, total now 46
# b708087b-aaec-44f5-9b8c-a76456f7fa67: 0 new matches, total now 97
# c58a2ab3-91c3-4384-83ce-bd30fb22de60 offset 0: 1 fetched, 1 new matches added
# c58a2ab3-91c3-4384-83ce-bd30fb22de60: 1 new matches, total now 44
# 2ae7a10a-b5f5-4844-aaba-7974059e61c1: 0 new matches, total now 39
# eb435bb1-c4fc-49d4-b289-8cae4de6a514: 0 new matches, total now 69
# d93116b1-534d-4666-bd5f-02f04b53ec07 offset 0: 2 fetched, 2 new matches added
# d93116b1-534d-4666-bd5f-02f04b53ec07: 2 new matches, total now 138
# 9bec1d6c-b44c-4596-8987-2078ea31a301: 0 new matches, total now 31
# fc12fac9-d6c0-4d59-991a-1b5468cbf80c offset 0: 1 fetched, 1 new matches added
# fc12fac9-d6c0-4d59-991a-1b5468cbf80c: 1 new matches, total now 26
# a43c82f3-0376-4fd9-bf84-f6f67f2ea670 offset 0: 3 fetched, 3 new matches added
# a43c82f3-0376-4fd9-bf84-f6f67f2ea670: 3 new matches, total now 83
# 62382347-448b-4584-b86f-c89c84a1137e offset 0: 2 fetched, 2 new matches added
# 62382347-448b-4584-b86f-c89c84a1137e: 2 new matches, total now 185
# d96667e1-0e54-4543-81a1-062909278852 offset 0: 4 fetched, 4 new matches added
# d96667e1-0e54-4543-81a1-062909278852: 4 new matches, total now 142
# 0e4b5c54-0e35-4fd0-a261-5486f756b44e offset 0: 7 fetched, 7 new matches added
# 0e4b5c54-0e35-4fd0-a261-5486f756b44e: 7 new matches, total now 180
# 2ec01edf-c73c-4818-b00d-68d9104b50be offset 0: 2 fetched, 2 new matches added
# 2ec01edf-c73c-4818-b00d-68d9104b50be: 2 new matches, total now 129
# 7dccb86f-6c6d-4505-91d9-ab62e9961fab offset 0: 5 fetched, 5 new matches added
# 7dccb86f-6c6d-4505-91d9-ab62e9961fab: 5 new matches, total now 55
# 1d1dc09c-8fd3-4f70-a59b-8d795c96af54 offset 0: 1 fetched, 1 new matches added
# 1d1dc09c-8fd3-4f70-a59b-8d795c96af54: 1 new matches, total now 117
# d15e9f85-12c3-4ad9-a174-6d0248d6393d offset 0: 5 fetched, 4 new matches added
# d15e9f85-12c3-4ad9-a174-6d0248d6393d: 4 new matches, total now 180
# c1585745-152b-446e-8929-ece350d96a56 offset 0: 11 fetched, 11 new matches added
# c1585745-152b-446e-8929-ece350d96a56: 11 new matches, total now 161
# 3d0c7a84-b2dd-409c-af47-d5f6040e4c11: 0 new matches, total now 84
# 5d7f559b-a077-4bd7-b355-e8bd9456d2e5 offset 0: 1 fetched, 1 new matches added
# 5d7f559b-a077-4bd7-b355-e8bd9456d2e5: 1 new matches, total now 91
# 8412ca6f-5246-4612-879b-435391f5080d offset 0: 1 fetched, 1 new matches added
# 8412ca6f-5246-4612-879b-435391f5080d: 1 new matches, total now 27
# e18d23c2-48c0-48d9-a09e-1de720185c26 offset 0: 1 fetched, 1 new matches added
# e18d23c2-48c0-48d9-a09e-1de720185c26: 1 new matches, total now 53
# d1f5edbf-b848-4464-98e9-dc4c2267cf95 offset 0: 3 fetched, 3 new matches added
# b58a31d5-8613-4deb-87ec-acc9b1addce8 offset 0: 1 fetched, 1 new matches added
# d1f5edbf-b848-4464-98e9-dc4c2267cf95: 3 new matches, total now 64
# b58a31d5-8613-4deb-87ec-acc9b1addce8: 1 new matches, total now 31
# d5f6dc48-c77b-4a80-8ee7-c15b9d78d38c offset 0: 6 fetched, 6 new matches added
# d5f6dc48-c77b-4a80-8ee7-c15b9d78d38c: 6 new matches, total now 62
# c352a24b-87f1-45a5-999a-cbb84515b2dd offset 0: 2 fetched, 2 new matches added
# c352a24b-87f1-45a5-999a-cbb84515b2dd: 2 new matches, total now 80
# 5b8b2a68-7eb8-44a7-9e30-f54e0d0d77a7 offset 0: 3 fetched, 3 new matches added
# 5b8b2a68-7eb8-44a7-9e30-f54e0d0d77a7: 3 new matches, total now 76
# 326de5e3-7fc4-4899-af53-4de745aa15a6 offset 0: 1 fetched, 1 new matches added
# 326de5e3-7fc4-4899-af53-4de745aa15a6: 1 new matches, total now 61
# 8d68257b-cb76-4fc3-80b2-0bfcecde010e offset 0: 3 fetched, 3 new matches added
# 8d68257b-cb76-4fc3-80b2-0bfcecde010e: 3 new matches, total now 81
# 17fb7f46-92c7-4110-a957-bcdcd6e5df37 offset 0: 4 fetched, 4 new matches added
# 17fb7f46-92c7-4110-a957-bcdcd6e5df37: 4 new matches, total now 176
# eca31921-03fc-489c-887e-546c73bc9071: 0 new matches, total now 23
# 9a67edda-5c5f-4696-b70d-033b71861eab offset 0: 4 fetched, 4 new matches added
# 9a67edda-5c5f-4696-b70d-033b71861eab: 4 new matches, total now 39
# 5b07ce52-42cc-488d-81e1-0c9b14acf811: 0 new matches, total now 38
# 46f643e5-011f-42c2-9532-99f6f0e094eb offset 0: 15 fetched, 15 new matches added
# 46f643e5-011f-42c2-9532-99f6f0e094eb: 15 new matches, total now 694
# 1ec885c6-d06a-4258-b29a-442a43741c61 offset 0: 1 fetched, 1 new matches added
# 1ec885c6-d06a-4258-b29a-442a43741c61: 1 new matches, total now 95
# ae032e7c-708c-4ecf-b612-24d7d03ab4b3 offset 0: 2 fetched, 2 new matches added
# ae032e7c-708c-4ecf-b612-24d7d03ab4b3: 2 new matches, total now 169
# deff5ea4-5013-4644-a5b6-5a52e57bf069: 0 new matches, total now 50
# 284d641a-5f70-4326-921c-f1c3f9389cbc offset 0: 1 fetched, 1 new matches added
# 284d641a-5f70-4326-921c-f1c3f9389cbc: 1 new matches, total now 42
# 65d09500-558f-4a6c-a1af-8b7b16d79a2b: 0 new matches, total now 82
# 6654a49c-9238-47dd-8640-185f131dc31a: 0 new matches, total now 250
# 76e00efd-48b3-4d99-a202-4a6a5c051dc6 offset 0: 2 fetched, 2 new matches added
# 76e00efd-48b3-4d99-a202-4a6a5c051dc6: 2 new matches, total now 50
# 9049a443-1d41-4ae1-9ef4-ad36e195302d offset 0: 3 fetched, 3 new matches added
# 9049a443-1d41-4ae1-9ef4-ad36e195302d: 3 new matches, total now 38
# cf6d1dd9-99df-4913-b265-c6f6acd1cd84 offset 0: 5 fetched, 5 new matches added
# cf6d1dd9-99df-4913-b265-c6f6acd1cd84: 5 new matches, total now 245
# 32a3bc95-f8d5-4215-9995-e7ca6459dfee offset 0: 1 fetched, 1 new matches added
# 32a3bc95-f8d5-4215-9995-e7ca6459dfee: 1 new matches, total now 133
# 3a915831-0dca-46ec-b9db-b1183ef8a4bf offset 0: 1 fetched, 1 new matches added
# 3a915831-0dca-46ec-b9db-b1183ef8a4bf: 1 new matches, total now 210
# 2458e8c5-5814-472e-8dd8-2666f9864e9a offset 0: 5 fetched, 5 new matches added
# 2458e8c5-5814-472e-8dd8-2666f9864e9a: 5 new matches, total now 203
# cb0fea3e-ec52-495e-acdc-bd0ce4834137 offset 0: 5 fetched, 5 new matches added
# cb0fea3e-ec52-495e-acdc-bd0ce4834137: 5 new matches, total now 167
# e4ba513e-a277-42bf-bd92-aef17216c9ed offset 0: 10 fetched, 10 new matches added
# e4ba513e-a277-42bf-bd92-aef17216c9ed: 10 new matches, total now 156
# e81250a4-a380-4149-b286-f9d8619a44ab: 0 new matches, total now 81
# 9d9616de-e463-49cc-9de6-b6c22f91b794 offset 0: 3 fetched, 3 new matches added
# 9d9616de-e463-49cc-9de6-b6c22f91b794: 3 new matches, total now 149
# 720aa205-50de-4f3e-a38a-ed0da0a8981e offset 0: 8 fetched, 8 new matches added
# 720aa205-50de-4f3e-a38a-ed0da0a8981e: 8 new matches, total now 259
# cf3aa4cb-03ef-4788-9fc1-83ef0290a95f: 0 new matches, total now 108
# afe4ce65-b6e0-4638-b623-beacd8c78256 offset 0: 4 fetched, 4 new matches added
# afe4ce65-b6e0-4638-b623-beacd8c78256: 4 new matches, total now 42
# 193bbbe9-196a-4f31-88a1-cb175ab070f8 offset 0: 5 fetched, 5 new matches added
# 193bbbe9-196a-4f31-88a1-cb175ab070f8: 5 new matches, total now 94
# 16535c6a-fbce-4485-b5b8-fab4340b707e offset 0: 1 fetched, 1 new matches added
# 16535c6a-fbce-4485-b5b8-fab4340b707e: 1 new matches, total now 189
# 5639411a-18eb-44de-9c46-284d4a478268 offset 0: 3 fetched, 3 new matches added
# 5639411a-18eb-44de-9c46-284d4a478268: 3 new matches, total now 116
# 91e3ca49-57ef-41d0-bee3-c654d60303be: 0 new matches, total now 242
# 6d6b6727-c90d-4e47-9201-38a935c2f259 offset 0: 3 fetched, 3 new matches added
# 6d6b6727-c90d-4e47-9201-38a935c2f259: 3 new matches, total now 210
# e47749a7-af5a-4383-bde6-084d5aa26cb3 offset 0: 2 fetched, 2 new matches added
# e47749a7-af5a-4383-bde6-084d5aa26cb3: 2 new matches, total now 177
# 18b2c04e-ab6b-454f-99e8-2434a20bd33b offset 0: 7 fetched, 7 new matches added
# 18b2c04e-ab6b-454f-99e8-2434a20bd33b: 7 new matches, total now 67
# 5f7845d6-3604-415d-831f-34b0ecc3a9bd: 0 new matches, total now 21
# c763355a-460d-4c45-be5a-a1e6a7d6f38f: 0 new matches, total now 211
# 86f57d61-3e1a-4333-8105-38888e6d75f4 offset 0: 10 fetched, 10 new matches added
# 86f57d61-3e1a-4333-8105-38888e6d75f4: 10 new matches, total now 244
# 693aea31-7245-48f2-a3d8-4cb6b0b3903c: 0 new matches, total now 2
# 5001848a-6e3b-4667-8d36-9b8db256a667 offset 0: 5 fetched, 5 new matches added
# 5001848a-6e3b-4667-8d36-9b8db256a667: 5 new matches, total now 132
# 0eb7ee24-d5f8-4373-972e-907f61e6aafb offset 0: 5 fetched, 5 new matches added
# 0eb7ee24-d5f8-4373-972e-907f61e6aafb: 5 new matches, total now 229
# e743f4a5-3421-4813-8a89-8695f6e84d6f: 0 new matches, total now 131
# 68764eb1-57df-43c8-b6a9-95b617a111c0 offset 0: 1 fetched, 1 new matches added
# 68764eb1-57df-43c8-b6a9-95b617a111c0: 1 new matches, total now 77
# 070f46d6-78cc-4da8-acd9-2267eca5c09e offset 0: 3 fetched, 3 new matches added
# 070f46d6-78cc-4da8-acd9-2267eca5c09e: 3 new matches, total now 154
# e0cc90d9-c5ee-4193-ab1d-cce10af44818 offset 0: 6 fetched, 6 new matches added
# e0cc90d9-c5ee-4193-ab1d-cce10af44818: 6 new matches, total now 128
# e05e2128-e0ab-459e-8ee5-4a0249ba508f offset 0: 8 fetched, 8 new matches added
# e05e2128-e0ab-459e-8ee5-4a0249ba508f: 8 new matches, total now 326
# 50fdd894-0abd-4b74-9c32-081ec282c6a5 offset 0: 3 fetched, 3 new matches added
# 50fdd894-0abd-4b74-9c32-081ec282c6a5: 3 new matches, total now 70
# a01b8331-c722-49d1-98ea-6d3bb499fe31 offset 0: 7 fetched, 7 new matches added
# a01b8331-c722-49d1-98ea-6d3bb499fe31: 7 new matches, total now 155
# 09b4639b-e070-4369-90da-8ec717da1402 offset 0: 1 fetched, 1 new matches added
# 09b4639b-e070-4369-90da-8ec717da1402: 1 new matches, total now 188
# bbdd26d9-6b0f-4d4e-a710-bfca20b97f79 offset 0: 1 fetched, 1 new matches added
# bbdd26d9-6b0f-4d4e-a710-bfca20b97f79: 1 new matches, total now 159
# 7ead4778-bfb6-45b3-b5c1-4fcac023cde7 offset 0: 1 fetched, 1 new matches added
# 7ead4778-bfb6-45b3-b5c1-4fcac023cde7: 1 new matches, total now 56
# c22bc079-24ef-4d2c-ac3a-4d478667e46a: 0 new matches, total now 78
# 50779fa6-a91e-4ec9-84cc-35e3653a5900 offset 0: 1 fetched, 1 new matches added
# 50779fa6-a91e-4ec9-84cc-35e3653a5900: 1 new matches, total now 37
# 11f0dce1-71f6-4032-8cf1-c41ab46e0103 offset 0: 1 fetched, 1 new matches added
# 11f0dce1-71f6-4032-8cf1-c41ab46e0103: 1 new matches, total now 186
# 0c0e9993-35f1-4012-a4e6-0cb1ad2447c2 offset 0: 3 fetched, 3 new matches added
# 0c0e9993-35f1-4012-a4e6-0cb1ad2447c2: 3 new matches, total now 227
# 5ed16fb3-4eda-4e0e-b20c-f18b7f2eeae2: 0 new matches, total now 33
# d958598c-4313-471f-8ba1-49c9606852ad: 0 new matches, total now 141
# b76e3630-50d2-471b-a67a-89d731abb6f6 offset 0: 1 fetched, 1 new matches added
# b76e3630-50d2-471b-a67a-89d731abb6f6: 1 new matches, total now 68
# 9e4b233b-5de8-4729-ab48-dbe303e29bb8: 0 new matches, total now 61
# c245fbb0-efb1-4b45-b83c-e0eb96e44894 offset 0: 5 fetched, 5 new matches added
# c245fbb0-efb1-4b45-b83c-e0eb96e44894: 5 new matches, total now 139
# 3f3ed5d1-6d27-4e27-86cc-47e8dcb5c990 offset 0: 4 fetched, 4 new matches added
# 3f3ed5d1-6d27-4e27-86cc-47e8dcb5c990: 4 new matches, total now 144
# 8a974d4c-1c2b-4469-9238-e750515eb140 offset 0: 1 fetched, 1 new matches added
# 8a974d4c-1c2b-4469-9238-e750515eb140: 1 new matches, total now 82
# c53d4a28-cf6c-4a1c-9e7d-229f5671f4ef offset 0: 3 fetched, 3 new matches added
# c53d4a28-cf6c-4a1c-9e7d-229f5671f4ef: 3 new matches, total now 81
# d75787ce-e682-4bf1-9565-50d5a5a5de71 offset 0: 1 fetched, 1 new matches added
# d75787ce-e682-4bf1-9565-50d5a5a5de71: 1 new matches, total now 119
# aad94642-1b3b-4847-98a8-b22aa91b6baa offset 0: 7 fetched, 7 new matches added
# aad94642-1b3b-4847-98a8-b22aa91b6baa: 7 new matches, total now 163
# 514c45a2-dea6-4242-8482-43593c6fe85d offset 0: 1 fetched, 1 new matches added
# 514c45a2-dea6-4242-8482-43593c6fe85d: 1 new matches, total now 65
# 40f9af41-08ce-4445-9050-46bceb4a0277 offset 0: 2 fetched, 2 new matches added
# 40f9af41-08ce-4445-9050-46bceb4a0277: 2 new matches, total now 59
# cb87df2f-28e4-46d0-a95b-2fa47fdd3f44 offset 0: 3 fetched, 3 new matches added
# cb87df2f-28e4-46d0-a95b-2fa47fdd3f44: 3 new matches, total now 163
# f24276ef-da68-40c2-afea-c7c344f37c34 offset 0: 1 fetched, 1 new matches added
# f24276ef-da68-40c2-afea-c7c344f37c34: 1 new matches, total now 119
# 9dad5e5f-4f29-4c15-b7d0-456c32dd79c4 offset 0: 5 fetched, 5 new matches added
# 9dad5e5f-4f29-4c15-b7d0-456c32dd79c4: 5 new matches, total now 72
# 562a8877-8844-466d-8c59-9a1b73692f06 offset 0: 1 fetched, 1 new matches added
# 562a8877-8844-466d-8c59-9a1b73692f06: 1 new matches, total now 63
# df3d5cb1-42f4-4d98-9fd2-ad16a24c6494: 0 new matches, total now 192
# 64fc9b58-88a2-4868-9ee7-cd558ebec7df offset 0: 1 fetched, 1 new matches added
# 64fc9b58-88a2-4868-9ee7-cd558ebec7df: 1 new matches, total now 39
# c8d678e1-787a-4678-ad6a-58a9aaacaf7d offset 0: 7 fetched, 6 new matches added
# c8d678e1-787a-4678-ad6a-58a9aaacaf7d: 6 new matches, total now 468
# b9749fbf-9a6d-43f5-91a4-177a6d898614 offset 0: 1 fetched, 1 new matches added
# b9749fbf-9a6d-43f5-91a4-177a6d898614: 1 new matches, total now 48
# fcff7a86-8c5c-4cc2-b248-0bb80f02b407 offset 0: 12 fetched, 12 new matches added
# fcff7a86-8c5c-4cc2-b248-0bb80f02b407: 12 new matches, total now 316
# 837ca7ad-af3f-4495-a914-6355b25644a3 offset 0: 1 fetched, 1 new matches added
# 837ca7ad-af3f-4495-a914-6355b25644a3: 1 new matches, total now 52
# 4ad73602-bf2e-49e4-9fb7-de132e49b763: 0 new matches, total now 26
# 8bc40f51-234f-41c4-9aeb-8342bf454257 offset 0: 2 fetched, 2 new matches added
# 8bc40f51-234f-41c4-9aeb-8342bf454257: 2 new matches, total now 138
# 009a6367-0d08-48c6-a9ed-14d67167ed7c offset 0: 1 fetched, 1 new matches added
# 009a6367-0d08-48c6-a9ed-14d67167ed7c: 1 new matches, total now 87
# 4a8f507c-5aed-4e8c-a762-32b37e9bd6ab offset 0: 5 fetched, 5 new matches added
# 4a8f507c-5aed-4e8c-a762-32b37e9bd6ab: 5 new matches, total now 107
# 798a2775-5f60-4ea5-adfe-69f2a03fcf6d offset 0: 3 fetched, 3 new matches added
# 798a2775-5f60-4ea5-adfe-69f2a03fcf6d: 3 new matches, total now 199
# 73d983c2-cfa8-4c09-9dab-4aa21ffdf29a offset 0: 2 fetched, 2 new matches added
# 73d983c2-cfa8-4c09-9dab-4aa21ffdf29a: 2 new matches, total now 86
# 8eb310b9-859d-42a6-9cd0-3dc62c5b6bb7 offset 0: 5 fetched, 4 new matches added
# 8eb310b9-859d-42a6-9cd0-3dc62c5b6bb7: 4 new matches, total now 331
# 3b71c5e2-4db9-4852-b2e0-bc1a51ea5055: 0 new matches, total now 350
# 08ae5db9-d670-4e6e-bd95-cbae9a4bc376 offset 0: 1 fetched, 1 new matches added
# 08ae5db9-d670-4e6e-bd95-cbae9a4bc376: 1 new matches, total now 69
# 42e83fa2-b6ea-44b6-bbf7-ae30ceb2a6c8 offset 0: 3 fetched, 3 new matches added
# 42e83fa2-b6ea-44b6-bbf7-ae30ceb2a6c8: 3 new matches, total now 203
# 2bb0b9ef-d2f7-4415-9d9d-81e1024b0495 offset 0: 1 fetched, 1 new matches added
# 2bb0b9ef-d2f7-4415-9d9d-81e1024b0495: 1 new matches, total now 104
# 0de13d54-38d1-4504-8008-58e67ce5aea0 offset 0: 4 fetched, 4 new matches added
# 0de13d54-38d1-4504-8008-58e67ce5aea0: 4 new matches, total now 164
# 8d36bb30-5808-4325-a31a-ddfd47c75d19 offset 0: 1 fetched, 1 new matches added
# 8d36bb30-5808-4325-a31a-ddfd47c75d19: 1 new matches, total now 58
# 0728f378-fa01-49b6-9d54-fd31c9990621 offset 0: 2 fetched, 2 new matches added
# 0728f378-fa01-49b6-9d54-fd31c9990621: 2 new matches, total now 40
# aa296b26-118a-4413-a488-926a5aa2bcd1 offset 0: 9 fetched, 7 new matches added
# aa296b26-118a-4413-a488-926a5aa2bcd1: 7 new matches, total now 306
# abc56f26-d2ae-45e1-adef-6cc301e4b45e offset 0: 1 fetched, 1 new matches added
# abc56f26-d2ae-45e1-adef-6cc301e4b45e: 1 new matches, total now 35
# 8b6eef13-5041-4809-92a7-7f74786cc068 offset 0: 1 fetched, 1 new matches added
# 8b6eef13-5041-4809-92a7-7f74786cc068: 1 new matches, total now 94
# 5e42f6d4-db54-4a1b-bfc4-cf73659c3412 offset 0: 1 fetched, 1 new matches added
# 5e42f6d4-db54-4a1b-bfc4-cf73659c3412: 1 new matches, total now 26
# fd16a07c-5735-4148-8859-3369feb41275 offset 0: 12 fetched, 12 new matches added
# fd16a07c-5735-4148-8859-3369feb41275: 12 new matches, total now 201
# 85f33b4f-9d91-4b4c-9048-7b237996236e offset 0: 10 fetched, 10 new matches added
# 85f33b4f-9d91-4b4c-9048-7b237996236e: 10 new matches, total now 160
# 29ba62dd-cb37-4b4c-bec7-af9eaf3aa29f: 0 new matches, total now 62
# 27817f68-a57d-49c2-a27f-e157a33e8a21 offset 0: 2 fetched, 2 new matches added
# 27817f68-a57d-49c2-a27f-e157a33e8a21: 2 new matches, total now 26
# 68e96159-acdb-4a1b-8194-12ad015dff41 offset 0: 2 fetched, 2 new matches added
# 68e96159-acdb-4a1b-8194-12ad015dff41: 2 new matches, total now 136
# 22942579-feda-47e0-b572-fbc26309a6c9 offset 0: 1 fetched, 1 new matches added
# 22942579-feda-47e0-b572-fbc26309a6c9: 1 new matches, total now 72
# d09d2759-e337-40dd-951c-6dd748180206 offset 0: 1 fetched, 1 new matches added
# d09d2759-e337-40dd-951c-6dd748180206: 1 new matches, total now 213
# 67df894b-dd07-42e5-83b7-a30f4becbe4b offset 0: 7 fetched, 7 new matches added
# 67df894b-dd07-42e5-83b7-a30f4becbe4b: 7 new matches, total now 282
# 689ff676-63a0-4b2e-92dc-98683dafe728 offset 0: 4 fetched, 4 new matches added
# 689ff676-63a0-4b2e-92dc-98683dafe728: 4 new matches, total now 130
# 642b920a-0f8b-49b2-b1d5-ee423925f593 offset 0: 1 fetched, 1 new matches added
# 642b920a-0f8b-49b2-b1d5-ee423925f593: 1 new matches, total now 260
# cbca9c7c-4f17-4a28-bb38-adc26de88bd0 offset 0: 5 fetched, 5 new matches added
# cbca9c7c-4f17-4a28-bb38-adc26de88bd0: 5 new matches, total now 202
# 72507c69-3922-4333-aa89-8c81d12c4826 offset 0: 5 fetched, 5 new matches added
# 72507c69-3922-4333-aa89-8c81d12c4826: 5 new matches, total now 211
# 564b94d2-0c8a-4ae0-9bfa-86dd8471f37d: 0 new matches, total now 101
# b8fe3f34-be77-49ba-a4ad-8238492611b1: 0 new matches, total now 57
# 7c813070-0422-44b1-8cc0-0e8e1229390f offset 0: 2 fetched, 2 new matches added
# 7c813070-0422-44b1-8cc0-0e8e1229390f: 2 new matches, total now 179
# 0df29eb3-9dbd-498a-a533-e787821e8b44 offset 0: 2 fetched, 2 new matches added
# 0df29eb3-9dbd-498a-a533-e787821e8b44: 2 new matches, total now 197
# 76cdad79-8482-4f1d-991e-54007ecfacdc offset 0: 4 fetched, 4 new matches added
# 76cdad79-8482-4f1d-991e-54007ecfacdc: 4 new matches, total now 104
# 52681b62-f70e-46f0-8ae7-85d9839f0f40: 0 new matches, total now 304
# 8f5ca789-5243-4c92-b04f-87b0af04df5d offset 0: 2 fetched, 2 new matches added
# 8f5ca789-5243-4c92-b04f-87b0af04df5d: 2 new matches, total now 270
# 57d0ffa1-44d3-4271-9360-f09bfb7e3466 offset 0: 2 fetched, 2 new matches added
# 57d0ffa1-44d3-4271-9360-f09bfb7e3466: 2 new matches, total now 258
# 519e3691-53a1-42ce-b1d9-01241d7b29d4 offset 0: 2 fetched, 2 new matches added
# 519e3691-53a1-42ce-b1d9-01241d7b29d4: 2 new matches, total now 229
# 50b62611-e713-46a7-a015-3c133d335a8f offset 0: 10 fetched, 10 new matches added
# 50b62611-e713-46a7-a015-3c133d335a8f: 10 new matches, total now 153
# 72dd2c94-ef04-4513-9233-74bcc9fc82bf offset 0: 3 fetched, 3 new matches added
# 72dd2c94-ef04-4513-9233-74bcc9fc82bf: 3 new matches, total now 55
# e4766ca0-d6df-495e-8b09-209781d1d1f6: 0 new matches, total now 99
# 5b93b72b-b157-4f6c-8acd-29febde07be3 offset 0: 4 fetched, 4 new matches added
# 5b93b72b-b157-4f6c-8acd-29febde07be3: 4 new matches, total now 201
# 6ae246a4-77ce-471d-8861-5f0e5f2ec78c: 0 new matches, total now 37
# 82ed91b3-2d07-4740-949c-6f5b5e99b33b offset 0: 5 fetched, 5 new matches added
# 82ed91b3-2d07-4740-949c-6f5b5e99b33b: 5 new matches, total now 138
# c6c072c6-429b-4632-ab63-5b09cd5a89b4: 0 new matches, total now 3
# 8f37956f-3544-46ff-a3a4-43eb906b2ba2 offset 0: 4 fetched, 4 new matches added
# 8f37956f-3544-46ff-a3a4-43eb906b2ba2: 4 new matches, total now 175
# 4f101379-91ae-4fc2-a94d-d23cc06e0e64 offset 0: 3 fetched, 3 new matches added
# 4f101379-91ae-4fc2-a94d-d23cc06e0e64: 3 new matches, total now 75
# 8930a9c2-3fc9-45d3-9d7e-03a092cae692 offset 0: 1 fetched, 1 new matches added
# 8930a9c2-3fc9-45d3-9d7e-03a092cae692: 1 new matches, total now 16
# e193c746-efde-4e45-9847-3f2c5a45251f offset 0: 1 fetched, 1 new matches added
# e193c746-efde-4e45-9847-3f2c5a45251f: 1 new matches, total now 89
# fa5d2a13-5297-4fc4-ad74-b470af77798a offset 0: 1 fetched, 1 new matches added
# fa5d2a13-5297-4fc4-ad74-b470af77798a: 1 new matches, total now 41
# 97ddfa7f-a7aa-484d-9825-2591f8b4a010: 0 new matches, total now 45
# a3e0cf84-20bc-431e-bbcb-72b0c4960443: 0 new matches, total now 101
# 98bd9a72-2c5f-4074-a80f-5dfdc8a79917 offset 0: 1 fetched, 1 new matches added
# 98bd9a72-2c5f-4074-a80f-5dfdc8a79917: 1 new matches, total now 53
# 449b9ab3-e659-4365-b82a-9c892b5400e6 offset 0: 1 fetched, 1 new matches added
# 449b9ab3-e659-4365-b82a-9c892b5400e6: 1 new matches, total now 162
# 2758d9f9-51dd-46d8-a735-395b8a50fb23 offset 0: 3 fetched, 3 new matches added
# 2758d9f9-51dd-46d8-a735-395b8a50fb23: 3 new matches, total now 57
# b814aa88-8e36-443e-b03b-46b55f84da4f offset 0: 1 fetched, 1 new matches added
# b814aa88-8e36-443e-b03b-46b55f84da4f: 1 new matches, total now 160
# ff3ba684-dfcf-4959-96f2-1ca98cfbc387: 0 new matches, total now 9
# b8290a0f-1d8e-424b-a3fd-8c7e8a56d654 offset 0: 2 fetched, 2 new matches added
# b8290a0f-1d8e-424b-a3fd-8c7e8a56d654: 2 new matches, total now 299
# 898f034b-61e8-423f-872e-2c51a7c3ab16 offset 0: 3 fetched, 3 new matches added
# 898f034b-61e8-423f-872e-2c51a7c3ab16: 3 new matches, total now 283
# 8e4b8dbc-66c0-4b5b-9464-405158125cae offset 0: 2 fetched, 2 new matches added
# 8e4b8dbc-66c0-4b5b-9464-405158125cae: 2 new matches, total now 140
# f0d5ea45-2f1b-4fa8-b8b7-957a817c85d1 offset 0: 6 fetched, 6 new matches added
# f0d5ea45-2f1b-4fa8-b8b7-957a817c85d1: 6 new matches, total now 205
# 29fac8a2-7df6-4385-b091-3aceb20003ba offset 0: 2 fetched, 2 new matches added
# 29fac8a2-7df6-4385-b091-3aceb20003ba: 2 new matches, total now 52
# 2d4cd246-7f91-47f2-a2dd-5a7715839571 offset 0: 2 fetched, 2 new matches added
# 2d4cd246-7f91-47f2-a2dd-5a7715839571: 2 new matches, total now 177
# 32663f37-6ffd-4b2f-a830-035e5c2d580c offset 0: 3 fetched, 3 new matches added
# 32663f37-6ffd-4b2f-a830-035e5c2d580c: 3 new matches, total now 195
# 9f256db6-c0bc-42e1-a067-1db9b05f3cfc offset 0: 13 fetched, 9 new matches added
# 9f256db6-c0bc-42e1-a067-1db9b05f3cfc: 9 new matches, total now 245
# 6fd6c102-0825-4989-919d-80ddea19f5f2: 0 new matches, total now 46
# e14fa655-05a9-47b2-b0a5-7d58372ae83c offset 0: 4 fetched, 4 new matches added
# e14fa655-05a9-47b2-b0a5-7d58372ae83c: 4 new matches, total now 226
# 4a15b5db-a87c-4d02-8f30-b7617fee4179: 0 new matches, total now 295
# 1a7c42d4-f57b-4b52-99a7-10f19d6a683c offset 0: 1 fetched, 1 new matches added
# 1a7c42d4-f57b-4b52-99a7-10f19d6a683c: 1 new matches, total now 91
# 3fb373f1-496a-487a-9fbe-8d5afd9d869a offset 0: 5 fetched, 5 new matches added
# 3fb373f1-496a-487a-9fbe-8d5afd9d869a: 5 new matches, total now 162
# d23064ae-23e1-4448-b5ad-1c293f208ed5: 0 new matches, total now 38
# 159069e0-7e7c-4e3e-989e-d9f723689e3a offset 0: 11 fetched, 8 new matches added
# 159069e0-7e7c-4e3e-989e-d9f723689e3a: 8 new matches, total now 163
# 9c193cc1-c674-4f10-8c8d-e3ad533fe5ee offset 0: 4 fetched, 4 new matches added
# 9c193cc1-c674-4f10-8c8d-e3ad533fe5ee: 4 new matches, total now 120
# b229f9a1-a952-4958-ae7e-f35f997775a0 offset 0: 14 fetched, 13 new matches added
# b229f9a1-a952-4958-ae7e-f35f997775a0: 13 new matches, total now 456
# 69d666d3-60a9-444c-849c-e343fb106c92: 0 new matches, total now 13
# cc18b2e7-8be9-4204-9870-5e2d6d6d353e offset 0: 1 fetched, 1 new matches added
# cc18b2e7-8be9-4204-9870-5e2d6d6d353e: 1 new matches, total now 141
# 07c17bbe-dfd7-4405-a80b-59b7686997a7 offset 0: 7 fetched, 7 new matches added
# 07c17bbe-dfd7-4405-a80b-59b7686997a7: 7 new matches, total now 163
# 608479cf-b39b-4b1c-9d0c-388580a95a24 offset 0: 3 fetched, 3 new matches added
# 608479cf-b39b-4b1c-9d0c-388580a95a24: 3 new matches, total now 121
# c7250a29-515b-4680-ac03-69c1a49f4078 offset 0: 1 fetched, 1 new matches added
# c7250a29-515b-4680-ac03-69c1a49f4078: 1 new matches, total now 71
# 21beff05-3a62-4f32-be0e-59e28db2d913 offset 0: 2 fetched, 2 new matches added
# 21beff05-3a62-4f32-be0e-59e28db2d913: 2 new matches, total now 56
# 1bb1969a-4aea-490b-b6fa-f9eb7269169e: 0 new matches, total now 66
# 5bf13b91-9b94-4e6d-a5d2-78c54ffeb277 offset 0: 9 fetched, 9 new matches added
# 5bf13b91-9b94-4e6d-a5d2-78c54ffeb277: 9 new matches, total now 236
# 3bfe05d4-2324-46e7-a841-897bc94462c1 offset 0: 1 fetched, 1 new matches added
# 3bfe05d4-2324-46e7-a841-897bc94462c1: 1 new matches, total now 84
# f2c4c924-61ce-4319-8ea0-1e0610ce06c5 offset 0: 1 fetched, 1 new matches added
# f2c4c924-61ce-4319-8ea0-1e0610ce06c5: 1 new matches, total now 141
# 83baa570-6eab-496e-92c6-7fff280e9261 offset 0: 3 fetched, 3 new matches added
# 83baa570-6eab-496e-92c6-7fff280e9261: 3 new matches, total now 173
# 45ab49b0-6c98-4231-9515-714d59425bda offset 0: 4 fetched, 4 new matches added
# 45ab49b0-6c98-4231-9515-714d59425bda: 4 new matches, total now 216
# 68b9f5f6-a714-4dcc-b958-004297e39ff3: 0 new matches, total now 243
# d733bef4-e181-4b71-bf2c-8e4b2226945e: 0 new matches, total now 69
# 42f411cc-30e3-4fbd-abe5-2ad1a9392004 offset 0: 1 fetched, 1 new matches added
# 42f411cc-30e3-4fbd-abe5-2ad1a9392004: 1 new matches, total now 192
# 1a2639ec-87a0-4962-b488-6890ba5e493a: 0 new matches, total now 104
# e4614642-0e97-48b5-a5dc-9197ceadb93e offset 0: 3 fetched, 3 new matches added
# e4614642-0e97-48b5-a5dc-9197ceadb93e: 3 new matches, total now 141
# 5f9afe1f-89ba-4c30-81a2-02cbe3760f2f: 0 new matches, total now 34
# 7b4d0772-b86d-40ae-a34b-27d0861730a9 offset 0: 2 fetched, 2 new matches added
# 7b4d0772-b86d-40ae-a34b-27d0861730a9: 2 new matches, total now 181
# 001df53a-75ff-460a-b999-95057267988b offset 0: 4 fetched, 4 new matches added
# 001df53a-75ff-460a-b999-95057267988b: 4 new matches, total now 60
# 22b33fdf-5a47-49a2-be6f-2cf6dd36f66a: 0 new matches, total now 111
# d2540279-1528-4f59-bfdc-dba0f311261b offset 0: 4 fetched, 4 new matches added
# d2540279-1528-4f59-bfdc-dba0f311261b: 4 new matches, total now 141
# 2013e4cc-3fec-4c83-9ece-24313273f22e offset 0: 7 fetched, 3 new matches added
# 2013e4cc-3fec-4c83-9ece-24313273f22e: 3 new matches, total now 248
# 57461f56-35ce-4632-9ac4-908b39423644 offset 0: 5 fetched, 5 new matches added
# 57461f56-35ce-4632-9ac4-908b39423644: 5 new matches, total now 170
# 51aa2155-4ba8-449d-a62b-99e9f0d0889c offset 0: 1 fetched, 1 new matches added
# 51aa2155-4ba8-449d-a62b-99e9f0d0889c: 1 new matches, total now 111
# 6e5f2386-a5e0-4272-bc66-75b889a1cf9e offset 0: 1 fetched, 1 new matches added
# 6e5f2386-a5e0-4272-bc66-75b889a1cf9e: 1 new matches, total now 93
# 547f6769-c9b4-484d-ab9b-7892b8b7c7b4: 0 new matches, total now 41
# 3059fa7d-48f2-464f-bb71-ae058408027f offset 0: 3 fetched, 3 new matches added
# 3059fa7d-48f2-464f-bb71-ae058408027f: 3 new matches, total now 103
# ca7b87ae-25c2-4794-87c6-8fd7818b1ea1 offset 0: 7 fetched, 7 new matches added
# ca7b87ae-25c2-4794-87c6-8fd7818b1ea1: 7 new matches, total now 164
# 82b43327-ccb4-415b-a307-fd24c0947865 offset 0: 1 fetched, 1 new matches added
# 82b43327-ccb4-415b-a307-fd24c0947865: 1 new matches, total now 41
# d5d982b8-b416-48c1-ae27-47d1ea0fafa5: 0 new matches, total now 206
# c70d3447-a6b2-4e4f-81fe-50ae9148d35b offset 0: 1 fetched, 0 new matches added
# c70d3447-a6b2-4e4f-81fe-50ae9148d35b: 0 new matches, total now 236
# 80393ec9-b945-4f65-b491-9049094afa7d offset 0: 6 fetched, 6 new matches added
# 80393ec9-b945-4f65-b491-9049094afa7d: 6 new matches, total now 128
# 7ffc57f7-9bd3-428b-9594-6b8bac5410ae: 0 new matches, total now 79
# 746fd536-1da8-4ae8-b502-1012ac3b1143: 0 new matches, total now 41
# eb86f494-289e-4dde-8778-2976541b2ecd offset 0: 3 fetched, 3 new matches added
# eb86f494-289e-4dde-8778-2976541b2ecd: 3 new matches, total now 138
# 29c51af6-acf5-4f45-90da-bc8cb4afde50 offset 0: 3 fetched, 3 new matches added
# 29c51af6-acf5-4f45-90da-bc8cb4afde50: 3 new matches, total now 125
# 5def86bf-4dfd-4bc3-aefe-e991a497e119 offset 0: 1 fetched, 1 new matches added
# 5def86bf-4dfd-4bc3-aefe-e991a497e119: 1 new matches, total now 175
# 5bc9cf4c-eb42-4566-ac72-5337d9705d39: 0 new matches, total now 156
# 30c9c2f2-3c8a-41be-9aed-26481ad19042: 0 new matches, total now 88
# cd4c569f-a6e3-43e0-9233-1ea08442abd3 offset 0: 2 fetched, 2 new matches added
# cd4c569f-a6e3-43e0-9233-1ea08442abd3: 2 new matches, total now 206
# 1587e652-b393-40ec-972b-5cb0cda33d0f: 0 new matches, total now 301
# 17627964-fe8b-4957-a11c-31e7a5fee914 offset 0: 10 fetched, 10 new matches added
# 17627964-fe8b-4957-a11c-31e7a5fee914: 10 new matches, total now 257
# 592db9d0-92bf-4c9d-abce-8973ad7e3bb4 offset 0: 1 fetched, 1 new matches added
# 592db9d0-92bf-4c9d-abce-8973ad7e3bb4: 1 new matches, total now 163
# bd4f0e5b-5c41-4159-811b-790da0716597 offset 0: 5 fetched, 5 new matches added
# bd4f0e5b-5c41-4159-811b-790da0716597: 5 new matches, total now 155
# 708f858b-b29a-4a75-a76f-c0c99d6cb7f3 offset 0: 1 fetched, 1 new matches added
# 708f858b-b29a-4a75-a76f-c0c99d6cb7f3: 1 new matches, total now 120
# b1a9a5e8-9314-4269-be4b-9729ff2b2206 offset 0: 5 fetched, 5 new matches added
# b1a9a5e8-9314-4269-be4b-9729ff2b2206: 5 new matches, total now 105
# e5cbb533-2f0a-4f90-b810-a77924ef0090 offset 0: 2 fetched, 2 new matches added
# e5cbb533-2f0a-4f90-b810-a77924ef0090: 2 new matches, total now 118
# 49ef1925-b47a-4cdc-ac42-5b9523ef509e offset 0: 1 fetched, 1 new matches added
# 49ef1925-b47a-4cdc-ac42-5b9523ef509e: 1 new matches, total now 121
# 75861516-18c3-440d-9928-1aa55ce30b9f offset 0: 3 fetched, 3 new matches added
# 75861516-18c3-440d-9928-1aa55ce30b9f: 3 new matches, total now 193
# 0f6678b3-4e79-4f36-999b-f662154d1619 offset 0: 6 fetched, 6 new matches added
# 0f6678b3-4e79-4f36-999b-f662154d1619: 6 new matches, total now 232
# beb84208-bfe7-426b-a668-fcecb7f146b0 offset 0: 4 fetched, 4 new matches added
# beb84208-bfe7-426b-a668-fcecb7f146b0: 4 new matches, total now 217
# 713c2286-1d7b-4969-91af-0457b2dfb5cb offset 0: 3 fetched, 3 new matches added
# 713c2286-1d7b-4969-91af-0457b2dfb5cb: 3 new matches, total now 104
# b4908315-fc0c-418d-bedb-2e9c1446bf06 offset 0: 3 fetched, 3 new matches added
# b4908315-fc0c-418d-bedb-2e9c1446bf06: 3 new matches, total now 293
# 468f5679-4053-424c-8d4d-6425e7cbe9de offset 0: 6 fetched, 6 new matches added
# 468f5679-4053-424c-8d4d-6425e7cbe9de: 6 new matches, total now 321
# 45b4cf2d-61a6-45c7-a240-460c8dbc400f: 0 new matches, total now 49
# ed40dbf5-4572-40d3-8b77-dd60ea534184 offset 0: 4 fetched, 4 new matches added
# ed40dbf5-4572-40d3-8b77-dd60ea534184: 4 new matches, total now 248
# b9d3e91d-c97b-48bb-8e46-142ffb4d2938 offset 0: 3 fetched, 3 new matches added
# b9d3e91d-c97b-48bb-8e46-142ffb4d2938: 3 new matches, total now 178
# 1fea6910-19b9-43d3-aac2-c612b1d95b08 offset 0: 5 fetched, 5 new matches added
# 1fea6910-19b9-43d3-aac2-c612b1d95b08: 5 new matches, total now 129
# 1d84f7b6-f027-4e94-8e6c-6c55880bafdf offset 0: 11 fetched, 11 new matches added
# 1d84f7b6-f027-4e94-8e6c-6c55880bafdf: 11 new matches, total now 343
# 8274e1dc-bee1-428b-acb7-d106ad7eebec: 0 new matches, total now 107
# 04e7de70-7508-42dd-991e-d258d1155154 offset 0: 3 fetched, 3 new matches added
# 04e7de70-7508-42dd-991e-d258d1155154: 3 new matches, total now 146
# b5a79dd0-dcdb-4f6d-9a1d-aa574953db57 offset 0: 5 fetched, 5 new matches added
# b5a79dd0-dcdb-4f6d-9a1d-aa574953db57: 5 new matches, total now 140
# 7cab2a8f-6c2c-490a-abd8-9c74e068c701: 0 new matches, total now 75
# 86a33900-b294-4869-96c8-466a8e398f65 offset 0: 5 fetched, 5 new matches added
# 86a33900-b294-4869-96c8-466a8e398f65: 5 new matches, total now 212
# 11571390-1c92-4187-98ff-ffe33a3244cb: 0 new matches, total now 133
# b49550e3-e627-4191-8edc-cd3d31997cc3 offset 0: 4 fetched, 3 new matches added
# b49550e3-e627-4191-8edc-cd3d31997cc3: 3 new matches, total now 126
# 4c869f41-4665-4919-9625-7334c27d65c3: 0 new matches, total now 59
# b6dec76c-d41e-4c8d-9506-1462adfbb9c0: 0 new matches, total now 90
# 2562ae77-3138-4008-8311-87ff0b3f1272 offset 0: 1 fetched, 1 new matches added0db20a3a-2979-4a05-9c47-52357d29ce07 offset 0: 1 fetched, 1 new matches added
#
# 2562ae77-3138-4008-8311-87ff0b3f1272: 1 new matches, total now 57
# 0db20a3a-2979-4a05-9c47-52357d29ce07: 1 new matches, total now 190
# 27599954-d295-41aa-8d5a-7aebb789bbb1 offset 0: 2 fetched, 2 new matches added
# 27599954-d295-41aa-8d5a-7aebb789bbb1: 2 new matches, total now 323
# 7eb89148-d57a-40e6-a6a1-42f4d92fdeb2 offset 0: 6 fetched, 6 new matches added
# 7eb89148-d57a-40e6-a6a1-42f4d92fdeb2: 6 new matches, total now 119
# 05fc3e5b-cfba-437a-86c0-5dbc38bc9d9d offset 0: 1 fetched, 1 new matches added
# 05fc3e5b-cfba-437a-86c0-5dbc38bc9d9d: 1 new matches, total now 147
# 4edb5f04-debb-40e1-8fb7-5bd90cb0aa7f: 0 new matches, total now 99
# 24cc2641-fcfc-49e7-9ac2-4354a77d0245: 0 new matches, total now 108
# 79008d0c-b456-4e9a-be90-99ee53199efd offset 0: 5 fetched, 5 new matches added
# 79008d0c-b456-4e9a-be90-99ee53199efd: 5 new matches, total now 145
# 5439fbc5-e1cb-48fc-ad37-7931d0ee92a0: 0 new matches, total now 82
# 92c1e1eb-b100-4a45-9e6c-9d93c911c7e1 offset 0: 5 fetched, 5 new matches added
# 92c1e1eb-b100-4a45-9e6c-9d93c911c7e1: 5 new matches, total now 163
# a95ae99a-0a32-4038-9d4b-4bb7f54a4c18: 0 new matches, total now 63
# 74fa16e8-ce49-4951-a930-f8765d673fd5 offset 0: 1 fetched, 1 new matches added
# 74fa16e8-ce49-4951-a930-f8765d673fd5: 1 new matches, total now 87
# 7b542411-881f-46e9-a76b-3477dca8c28e offset 0: 3 fetched, 3 new matches added
# 7b542411-881f-46e9-a76b-3477dca8c28e: 3 new matches, total now 166
# 34fad33f-f0cb-4cea-aa92-73d1d054fe6f: 0 new matches, total now 66
# 63abbd64-375a-45e3-946b-664239d81f91: 0 new matches, total now 17
# 3504304c-5b4d-411f-9a16-27ba16784518: 0 new matches, total now 25
# 407ac242-5da4-468d-b978-1a5f01a46a70 offset 0: 2 fetched, 2 new matches added
# 407ac242-5da4-468d-b978-1a5f01a46a70: 2 new matches, total now 114
# d92a9305-bb86-47b6-ac91-73a323743e68 offset 0: 2 fetched, 2 new matches added
# d92a9305-bb86-47b6-ac91-73a323743e68: 2 new matches, total now 103
# 28d25f3c-f77f-44f8-9142-ddc3454aef09 offset 0: 5 fetched, 5 new matches added
# 28d25f3c-f77f-44f8-9142-ddc3454aef09: 5 new matches, total now 198
# d8bedfa7-67e1-45dc-83a8-ca209cb415b9 offset 0: 4 fetched, 4 new matches added
# d8bedfa7-67e1-45dc-83a8-ca209cb415b9: 4 new matches, total now 79
# cbb60429-14de-4636-8e9c-2a06dc245772 offset 0: 5 fetched, 5 new matches added
# cbb60429-14de-4636-8e9c-2a06dc245772: 5 new matches, total now 249
# ed0b1a6a-d042-49cc-99c5-a5f78ffcd237 offset 0: 6 fetched, 6 new matches added
# ed0b1a6a-d042-49cc-99c5-a5f78ffcd237: 6 new matches, total now 41
# cda91a1b-0d56-4bce-adf1-031e8e1f8998: 0 new matches, total now 189
# 67f2c045-f382-400b-a757-48062ebfa87d offset 0: 1 fetched, 1 new matches added
# 67f2c045-f382-400b-a757-48062ebfa87d: 1 new matches, total now 84
# 03f13dec-532c-45b4-8ed6-989a824fbb21 offset 0: 1 fetched, 1 new matches added
# 03f13dec-532c-45b4-8ed6-989a824fbb21: 1 new matches, total now 113
# 1264d291-3e78-46cc-93f0-91c7b93f8a35: 0 new matches, total now 28
# 46f90313-07c2-40f2-acdc-0210b51f7dd5: 0 new matches, total now 59
# 152377b4-13b3-4037-8dc5-e8e00edfe7e5 offset 0: 1 fetched, 1 new matches added
# 152377b4-13b3-4037-8dc5-e8e00edfe7e5: 1 new matches, total now 44
# 63ed0fb9-82ad-47f7-8da3-cab5d7cfc825: 0 new matches, total now 212
# ea91eaa0-2a85-49dc-8cf0-b10a3a5b565c offset 0: 6 fetched, 6 new matches added
# ea91eaa0-2a85-49dc-8cf0-b10a3a5b565c: 6 new matches, total now 182
# 3f3a7746-1977-4d55-b96a-b642fe9c3a72 offset 0: 2 fetched, 2 new matches added
# 3f3a7746-1977-4d55-b96a-b642fe9c3a72: 2 new matches, total now 127
# fb4f1653-768e-4229-9f75-0212f5e5b8c3: 0 new matches, total now 170
# bd9d8adb-8933-4126-803e-29aa86eecaf5 offset 0: 5 fetched, 5 new matches added
# bd9d8adb-8933-4126-803e-29aa86eecaf5: 5 new matches, total now 127
# 3ca17033-f905-4d42-a979-b3dc93aefe27 offset 0: 1 fetched, 1 new matches added
# 3ca17033-f905-4d42-a979-b3dc93aefe27: 1 new matches, total now 42
# 83f10b73-1139-4cab-9457-51f2f558419e: 0 new matches, total now 148
# 4dc0f531-5a5f-4ff4-a157-7b6b8a044ef5: 0 new matches, total now 52
# 10899b21-ab4d-44a0-8467-3b44c3e2b983 offset 0: 2 fetched, 2 new matches added
# 10899b21-ab4d-44a0-8467-3b44c3e2b983: 2 new matches, total now 89
# 2f672ed0-944a-45e0-a41b-7eb69c807dbf offset 0: 1 fetched, 1 new matches added
# 2f672ed0-944a-45e0-a41b-7eb69c807dbf: 1 new matches, total now 148
# fc247104-a25a-43d6-b813-ee8ab2c1107b offset 0: 1 fetched, 1 new matches added
# fc247104-a25a-43d6-b813-ee8ab2c1107b: 1 new matches, total now 122
# 55ef7120-2605-4865-a826-01c6958f53c0 offset 0: 12 fetched, 4 new matches added
# 55ef7120-2605-4865-a826-01c6958f53c0: 4 new matches, total now 264
# 27534d9d-bd4c-4204-be12-bdf007eda40c offset 0: 6 fetched, 6 new matches added
# 27534d9d-bd4c-4204-be12-bdf007eda40c: 6 new matches, total now 108
# 6e750194-77b3-4bdb-893b-d70fe529521c offset 0: 3 fetched, 3 new matches added
# 6e750194-77b3-4bdb-893b-d70fe529521c: 3 new matches, total now 65
# 32be50b0-bd27-4910-af31-b70761b4cecb offset 0: 7 fetched, 5 new matches added
# 32be50b0-bd27-4910-af31-b70761b4cecb: 5 new matches, total now 210
# c3faf504-e2b7-4713-9a19-fdf351d712fb: 0 new matches, total now 11
# 77da205d-fa2b-47c9-93b0-808e8e912949 offset 0: 7 fetched, 7 new matches added
# 77da205d-fa2b-47c9-93b0-808e8e912949: 7 new matches, total now 81
# e7a76197-944c-46eb-b4cb-ecfae55056d0 offset 0: 1 fetched, 1 new matches added
# e7a76197-944c-46eb-b4cb-ecfae55056d0: 1 new matches, total now 89
# 6fb74e7c-1265-4ece-81a1-8762854795d8 offset 0: 6 fetched, 6 new matches added
# 6fb74e7c-1265-4ece-81a1-8762854795d8: 6 new matches, total now 257
# ce6eea98-f189-42d5-b232-2302afd634ab offset 0: 1 fetched, 1 new matches added
# ce6eea98-f189-42d5-b232-2302afd634ab: 1 new matches, total now 67
# 050892d2-433c-4598-8d66-12856ad4ce89 offset 0: 3 fetched, 3 new matches added
# 050892d2-433c-4598-8d66-12856ad4ce89: 3 new matches, total now 160
# 68ab64bf-49fd-4d0e-8273-3ce59a452677 offset 0: 5 fetched, 5 new matches added
# 68ab64bf-49fd-4d0e-8273-3ce59a452677: 5 new matches, total now 109
# 80445ae3-2958-4871-a620-25ae6e31e37e: 0 new matches, total now 97
# c264f560-930f-4cc9-8568-389af941d5d3 offset 0: 1 fetched, 1 new matches added
# c264f560-930f-4cc9-8568-389af941d5d3: 1 new matches, total now 53
# 78fe33e9-dc5e-4537-a67f-a812a234a585 offset 0: 1 fetched, 1 new matches added
# 78fe33e9-dc5e-4537-a67f-a812a234a585: 1 new matches, total now 125
# 50d251fa-ef2c-41b2-9c91-06eb2d4726a5 offset 0: 5 fetched, 4 new matches added
# 50d251fa-ef2c-41b2-9c91-06eb2d4726a5: 4 new matches, total now 334
# 1f8c5652-d2af-4788-a97b-33287b6944e7: 0 new matches, total now 70
# d7729461-ed79-4a74-bec9-098383d9a7a0 offset 0: 5 fetched, 5 new matches added
# d7729461-ed79-4a74-bec9-098383d9a7a0: 5 new matches, total now 167
# 919eaa84-b74c-4d96-bbaa-a599af2d67c5 offset 0: 6 fetched, 6 new matches added
# 919eaa84-b74c-4d96-bbaa-a599af2d67c5: 6 new matches, total now 341
# 9efe0afc-fbc0-4930-b536-18dd3935cc72 offset 0: 6 fetched, 6 new matches added
# 9efe0afc-fbc0-4930-b536-18dd3935cc72: 6 new matches, total now 183
# 0d65f224-bc6e-4521-b23a-d90c8e5d4b87 offset 0: 1 fetched, 1 new matches added
# 0d65f224-bc6e-4521-b23a-d90c8e5d4b87: 1 new matches, total now 40
# b0e6d782-b60b-464b-b825-0551219d184c offset 0: 1 fetched, 1 new matches added
# b0e6d782-b60b-464b-b825-0551219d184c: 1 new matches, total now 70
# 595e8bea-9c02-42ab-b689-9a6589e79eb4 offset 0: 3 fetched, 3 new matches added
# 595e8bea-9c02-42ab-b689-9a6589e79eb4: 3 new matches, total now 159
# 40390516-123b-490c-b974-182ff8eafb7d offset 0: 4 fetched, 4 new matches added
# 40390516-123b-490c-b974-182ff8eafb7d: 4 new matches, total now 101
# f059fe12-1117-4fef-8303-ce16d287584d offset 0: 5 fetched, 5 new matches added
# f059fe12-1117-4fef-8303-ce16d287584d: 5 new matches, total now 168
# c7ddba66-d00c-4024-b64c-b8ca02611cb2 offset 0: 3 fetched, 3 new matches added
# c7ddba66-d00c-4024-b64c-b8ca02611cb2: 3 new matches, total now 186
# 7556f7a4-a21d-4e25-adb5-c3c168c89aea offset 0: 1 fetched, 1 new matches added
# 7556f7a4-a21d-4e25-adb5-c3c168c89aea: 1 new matches, total now 35
# 501f101c-b4c4-42e5-a25d-c46326316e5c offset 0: 4 fetched, 2 new matches added
# 501f101c-b4c4-42e5-a25d-c46326316e5c: 2 new matches, total now 77
# ed19e851-7551-4120-b5c1-a9310cf95962 offset 0: 11 fetched, 11 new matches added
# ed19e851-7551-4120-b5c1-a9310cf95962: 11 new matches, total now 252
# f4154391-4a82-4934-92d2-17c090e701c7 offset 0: 1 fetched, 1 new matches added
# f4154391-4a82-4934-92d2-17c090e701c7: 1 new matches, total now 143
# a31e926e-efb1-429e-9075-585a73eca5c2: 0 new matches, total now 59
# 27baf418-fa4c-4124-98e8-eb0e012f8256 offset 0: 2 fetched, 2 new matches added
# 27baf418-fa4c-4124-98e8-eb0e012f8256: 2 new matches, total now 93
# a4bca719-195f-423e-96d8-07398d65d069: 0 new matches, total now 224
# 8857a5f4-977c-4d3e-a3e1-bf72d6ffa76b offset 0: 1 fetched, 1 new matches added
# 8857a5f4-977c-4d3e-a3e1-bf72d6ffa76b: 1 new matches, total now 114
# 04b383d3-906c-40f6-a1f5-8c4fb58187e8: 0 new matches, total now 189
# 87896bc2-ec58-418d-babd-680d51ec1a12: 0 new matches, total now 39
# d3b73391-7c2f-49d8-9029-4eb35b53aadd offset 0: 4 fetched, 4 new matches added
# d3b73391-7c2f-49d8-9029-4eb35b53aadd: 4 new matches, total now 349
# cacdc465-a6fc-4950-bacf-ee652785ca6d offset 0: 2 fetched, 2 new matches added
# cacdc465-a6fc-4950-bacf-ee652785ca6d: 2 new matches, total now 54
# 095e3ce4-483b-497b-8541-bbf259653bc7 offset 0: 6 fetched, 6 new matches added
# 095e3ce4-483b-497b-8541-bbf259653bc7: 6 new matches, total now 44
# d87850b0-dfd6-4cfa-81c9-7836f4166308 offset 0: 1 fetched, 1 new matches added
# d87850b0-dfd6-4cfa-81c9-7836f4166308: 1 new matches, total now 226
# 860afa47-1cbb-4f0e-a8ed-ca443ac1eafc offset 0: 3 fetched, 3 new matches added
# 860afa47-1cbb-4f0e-a8ed-ca443ac1eafc: 3 new matches, total now 99
# e10645ee-1b87-448c-9c06-4f4fbc24efb1 offset 0: 17 fetched, 12 new matches added
# e10645ee-1b87-448c-9c06-4f4fbc24efb1: 12 new matches, total now 417
# d64b5480-4126-4feb-80cf-193f97030666 offset 0: 1 fetched, 1 new matches added
# d64b5480-4126-4feb-80cf-193f97030666: 1 new matches, total now 86
# 6e54cdfd-7d0a-4c59-bc58-64060db749d8 offset 0: 5 fetched, 5 new matches added
# 6e54cdfd-7d0a-4c59-bc58-64060db749d8: 5 new matches, total now 226
# 91b94988-c2b8-42c5-8947-0a0223743d2a: 0 new matches, total now 118
# 978fdf53-7709-4378-b34f-c4a8f1413e24 offset 0: 4 fetched, 4 new matches added
# 978fdf53-7709-4378-b34f-c4a8f1413e24: 4 new matches, total now 107
# 5953b5a3-f38f-4f42-9e1a-52e1419188d2 offset 0: 2 fetched, 2 new matches added
# 5953b5a3-f38f-4f42-9e1a-52e1419188d2: 2 new matches, total now 108
# e05956fd-4250-4ba0-8c55-ae63c409d18a: 0 new matches, total now 143
# 1e4ea2c2-6ca7-4291-b8fe-01f5bea8c81c offset 0: 7 fetched, 7 new matches added
# 1e4ea2c2-6ca7-4291-b8fe-01f5bea8c81c: 7 new matches, total now 386
# 176bb286-f737-4678-b3f0-ad6dab8f1275 offset 0: 2 fetched, 2 new matches added
# 176bb286-f737-4678-b3f0-ad6dab8f1275: 2 new matches, total now 75
# 2b44be0b-68e3-4a46-9cb6-b5678dbd4fe6: 0 new matches, total now 107
# 1477dbac-38c2-43ad-9675-0e22d9c34f37: 0 new matches, total now 116
# f4e5264e-6a22-4e07-a1ed-3f557ada6f8e: 0 new matches, total now 112
# 9fdf916f-f89d-4500-b235-f651708b03a2: 0 new matches, total now 70
# 2a36f86a-e888-466a-8814-bafce67664db offset 0: 1 fetched, 1 new matches added
# 2a36f86a-e888-466a-8814-bafce67664db: 1 new matches, total now 141
# 14352b25-d881-4552-b8bb-0e8361eb1427: 0 new matches, total now 131
# 10b9dcfe-6005-400b-8d0b-000171945e30 offset 0: 2 fetched, 2 new matches added
# 10b9dcfe-6005-400b-8d0b-000171945e30: 2 new matches, total now 141
# bb5fdebb-758a-4a88-9659-3b5d749cb9fc: 0 new matches, total now 141
# 732e701e-af89-423b-a619-84330d38428c offset 0: 1 fetched, 1 new matches added
# 732e701e-af89-423b-a619-84330d38428c: 1 new matches, total now 117
# df0a7153-3139-4091-a97f-709a43f589f1: 0 new matches, total now 329
# a9f6cec3-578e-4585-8270-258f6adb658b offset 0: 1 fetched, 1 new matches added
# a9f6cec3-578e-4585-8270-258f6adb658b: 1 new matches, total now 107
# 859ed47a-75a0-4863-89d6-02146adadb2a offset 0: 5 fetched, 5 new matches added
# 859ed47a-75a0-4863-89d6-02146adadb2a: 5 new matches, total now 132
# ad5d8ee1-defc-4c01-8370-487249db46dd offset 0: 4 fetched, 4 new matches added
# ad5d8ee1-defc-4c01-8370-487249db46dd: 4 new matches, total now 142
# d4c8fb70-d6f4-4679-a275-bda565e5e731 offset 0: 8 fetched, 8 new matches added
# d4c8fb70-d6f4-4679-a275-bda565e5e731: 8 new matches, total now 320
# 613746a2-7666-4ffc-9fc6-9ec1e2ba5751 offset 0: 1 fetched, 1 new matches added
# 613746a2-7666-4ffc-9fc6-9ec1e2ba5751: 1 new matches, total now 88
# fe28359b-ffb0-407b-8212-2c0b02a50a7f: 0 new matches, total now 352
# a9c7a112-bc35-45ac-a850-181124cab1ab offset 0: 1 fetched, 1 new matches added
# a9c7a112-bc35-45ac-a850-181124cab1ab: 1 new matches, total now 107
# dc062771-7ad1-4bdb-ae0c-a058caaafe1e offset 0: 1 fetched, 1 new matches added
# dc062771-7ad1-4bdb-ae0c-a058caaafe1e: 1 new matches, total now 132
# ff35cedf-60ca-4f2a-a38d-6eb13e615074 offset 0: 2 fetched, 2 new matches added
# ff35cedf-60ca-4f2a-a38d-6eb13e615074: 2 new matches, total now 163
# ...
# 5dd1aa8a-948c-4950-8cba-4e2c2c0d8e5d: 4 new matches, total now 232
# 09013c50-c5af-4a4e-bbc9-83ba08c00fc0 offset 0: 12 fetched, 10 new matches added
# 09013c50-c5af-4a4e-bbc9-83ba08c00fc0: 10 new matches, total now 273
# 59cb74a0-e713-4b83-ae52-83ac0a39682a offset 0: 1 fetched, 1 new matches added
# 59cb74a0-e713-4b83-ae52-83ac0a39682a: 1 new matches, total now 82
# 8e9c1396-953d-46c0-ba4f-39c9a8d5b9f6: 0 new matches, total now 49
# a2df7ed7-29b5-407b-8833-06c169f73d7c: 0 new matches, total now 157
# 2c36eaa9-02b8-4512-8540-64a391850b25: 0 new matches, total now 9
# 5ac0708a-1a06-44e8-85e1-99a9b020892f offset 0: 6 fetched, 6 new matches added
# 5ac0708a-1a06-44e8-85e1-99a9b020892f: 6 new matches, total now 195
# fbb6f5b8-c8ce-415d-b29f-374d6b543716 offset 0: 1 fetched, 1 new matches added
# fbb6f5b8-c8ce-415d-b29f-374d6b543716: 1 new matches, total now 112
# 00bf976c-8607-40b8-a174-9b9261502c4f offset 0: 5 fetched, 5 new matches added
# 00bf976c-8607-40b8-a174-9b9261502c4f: 5 new matches, total now 153
# 4907b87f-d106-419e-8853-14c582bac90f offset 0: 3 fetched, 3 new matches added
# 4907b87f-d106-419e-8853-14c582bac90f: 3 new matches, total now 120
# 7fab7b4d-b036-4b79-8ea2-abcbab2a463f offset 0: 5 fetched, 5 new matches added
# 7fab7b4d-b036-4b79-8ea2-abcbab2a463f: 5 new matches, total now 99
# a809c291-c2aa-4d35-9391-68b8141ca5ea: 0 new matches, total now 18
# 0f0d97ac-e05a-4444-9514-7cb6ed1d103d offset 0: 1 fetched, 1 new matches added
# 0f0d97ac-e05a-4444-9514-7cb6ed1d103d: 1 new matches, total now 74
# 30917752-3329-468e-a6ef-760365b64a15 offset 0: 2 fetched, 2 new matches added
# 30917752-3329-468e-a6ef-760365b64a15: 2 new matches, total now 52
# 96201495-4bc6-46b9-9981-61e96c458af7 offset 0: 14 fetched, 12 new matches added
# 96201495-4bc6-46b9-9981-61e96c458af7: 12 new matches, total now 361
# 35d9152c-0fb2-422a-aefa-d49b7a8d6465 offset 0: 10 fetched, 7 new matches added
# 35d9152c-0fb2-422a-aefa-d49b7a8d6465: 7 new matches, total now 299
# 4705438f-25ce-4fb3-980b-81a2bddb27b9: 0 new matches, total now 629
# 4f70293f-3aed-4462-bfea-ef518601a90a offset 0: 4 fetched, 4 new matches added
# 4f70293f-3aed-4462-bfea-ef518601a90a: 4 new matches, total now 273
# 37ecbadd-58bf-48fc-a5a8-3b4357c63f03 offset 0: 6 fetched, 6 new matches added
# 37ecbadd-58bf-48fc-a5a8-3b4357c63f03: 6 new matches, total now 147
# 4540d263-41dd-4beb-a63f-dce2fc2b8c35 offset 0: 1 fetched, 1 new matches added
# 4540d263-41dd-4beb-a63f-dce2fc2b8c35: 1 new matches, total now 94
# 15037198-ce87-46aa-9f25-f09264c4fbd3 offset 0: 3 fetched, 3 new matches added
# 15037198-ce87-46aa-9f25-f09264c4fbd3: 3 new matches, total now 102
# 28f69c28-33da-4f37-a20d-e4182835fce8: 0 new matches, total now 114
# 02b26fe9-49d1-47e7-afa0-1b5c562ca4e2 offset 0: 10 fetched, 7 new matches added
# 02b26fe9-49d1-47e7-afa0-1b5c562ca4e2: 7 new matches, total now 242
# 6052043d-e75e-41b3-9224-c5be94486bb4 offset 0: 8 fetched, 8 new matches added
# 6052043d-e75e-41b3-9224-c5be94486bb4: 8 new matches, total now 184
# 33746a22-e357-4b2b-bd7b-58c38da3422f: 0 new matches, total now 59
# dba627b3-708d-47c6-a99b-2b8b89b556e8: 0 new matches, total now 155
# 216ea590-bdbe-4040-89eb-d4327231e2fd offset 0: 1 fetched, 1 new matches added
# 216ea590-bdbe-4040-89eb-d4327231e2fd: 1 new matches, total now 122
# 6c48ec88-034e-4c59-8a41-38c8bd308d2c offset 0: 1 fetched, 1 new matches added
# 6c48ec88-034e-4c59-8a41-38c8bd308d2c: 1 new matches, total now 83
# f9f106f0-68c4-46c0-a347-09c8ea244538: 0 new matches, total now 139
# 3c0c7bf5-5fc2-418f-9010-9c8e699eff4a offset 0: 1 fetched, 1 new matches added
# 3c0c7bf5-5fc2-418f-9010-9c8e699eff4a: 1 new matches, total now 216
# 28a21ee2-fd3f-4914-b2a7-230bd84e071e offset 0: 2 fetched, 2 new matches added
# 28a21ee2-fd3f-4914-b2a7-230bd84e071e: 2 new matches, total now 149
# 1ed77767-b378-42ff-b4a8-10bf75aed27b offset 0: 6 fetched, 6 new matches added
# 1ed77767-b378-42ff-b4a8-10bf75aed27b: 6 new matches, total now 80
# 544ecb3c-fa28-49fe-abf1-7a8991bb7a62 offset 0: 2 fetched, 2 new matches added
# 544ecb3c-fa28-49fe-abf1-7a8991bb7a62: 2 new matches, total now 135
# 8f61f717-9d71-435e-8972-28aa4f94ac17: 0 new matches, total now 259
# 0da2299d-3a87-4bfd-a544-ce58f55b0ebc: 0 new matches, total now 66
# f731c46b-35dc-4281-9180-1beb7a127360 offset 0: 2 fetched, 2 new matches added
# f731c46b-35dc-4281-9180-1beb7a127360: 2 new matches, total now 52
# 500bde66-b956-4d05-83c8-56de4f94f82a offset 0: 1 fetched, 1 new matches added
# 500bde66-b956-4d05-83c8-56de4f94f82a: 1 new matches, total now 106
# 2cdacd36-de78-46c0-804e-65623b405d51 offset 0: 3 fetched, 3 new matches added
# 2cdacd36-de78-46c0-804e-65623b405d51: 3 new matches, total now 122
# e6850c53-486a-44bf-97ba-113c1f54fed6 offset 0: 9 fetched, 9 new matches added
# e6850c53-486a-44bf-97ba-113c1f54fed6: 9 new matches, total now 97
# 2d18f8ec-3383-4f0f-a254-b0fdb2385d12: 0 new matches, total now 38
# c4fbe1e6-df5f-42ea-8a7f-addcf635d82f offset 0: 1 fetched, 1 new matches added
# c4fbe1e6-df5f-42ea-8a7f-addcf635d82f: 1 new matches, total now 71
# 8fcd5007-36ba-418d-ad74-7f857912ce10 offset 0: 1 fetched, 1 new matches added
# 8fcd5007-36ba-418d-ad74-7f857912ce10: 1 new matches, total now 87
# 4b657a70-c18c-4526-a787-ae83578155bb offset 0: 7 fetched, 7 new matches added
# 4b657a70-c18c-4526-a787-ae83578155bb: 7 new matches, total now 344
# e2f63721-3b90-4805-a73d-6a63616c00c3: 0 new matches, total now 60
# 6a8c42f1-b66d-49d3-a89a-d0fd7c11d544 offset 0: 6 fetched, 6 new matches added
# 6a8c42f1-b66d-49d3-a89a-d0fd7c11d544: 6 new matches, total now 169
# 4594c3f0-f3ba-4bdf-ad59-3dbc53fad224 offset 0: 16 fetched, 12 new matches added
# 4594c3f0-f3ba-4bdf-ad59-3dbc53fad224: 12 new matches, total now 356
# 7755ecad-986d-418d-932e-2250132bee75 offset 0: 8 fetched, 3 new matches added
# 7755ecad-986d-418d-932e-2250132bee75: 3 new matches, total now 404
# 20704051-31fb-4bdd-84b6-0d8f04af3560: 0 new matches, total now 161
# 92ee0dcb-6fc3-4541-b03b-2abaccce6795 offset 0: 8 fetched, 8 new matches added
# 92ee0dcb-6fc3-4541-b03b-2abaccce6795: 8 new matches, total now 168
# cc3f89e5-10a9-4f9a-be43-d9b01e5cd6b2: 0 new matches, total now 168
# 14550649-9b4c-47e5-a33e-afa3363c4afd offset 0: 2 fetched, 2 new matches added
# 14550649-9b4c-47e5-a33e-afa3363c4afd: 2 new matches, total now 89
# 3933d1f1-6a23-489a-b87c-a3a0c70bf816 offset 0: 1 fetched, 1 new matches added
# 3933d1f1-6a23-489a-b87c-a3a0c70bf816: 1 new matches, total now 118
# 0cfedab5-e1fd-4682-bd80-e48128110235 offset 0: 3 fetched, 3 new matches added
# 0cfedab5-e1fd-4682-bd80-e48128110235: 3 new matches, total now 104
# 0f98d6b4-4d24-4ea5-890e-8e0ccdedd2a2 offset 0: 1 fetched, 1 new matches added
# 0f98d6b4-4d24-4ea5-890e-8e0ccdedd2a2: 1 new matches, total now 108
# 9b0d27e6-d0cc-4949-be7d-a48c40603f3a offset 0: 1 fetched, 1 new matches added
# 9b0d27e6-d0cc-4949-be7d-a48c40603f3a: 1 new matches, total now 110
# e8a4e09c-dfdd-4a33-bc04-99f639436d43 offset 0: 9 fetched, 3 new matches added
# e8a4e09c-dfdd-4a33-bc04-99f639436d43: 3 new matches, total now 139
# 08196164-0f68-4185-8370-f71cb4e94c05 offset 0: 1 fetched, 1 new matches added
# 08196164-0f68-4185-8370-f71cb4e94c05: 1 new matches, total now 65
# c8682f0d-9c75-4256-abd5-2b562a1a0a2b offset 0: 6 fetched, 6 new matches added
# c8682f0d-9c75-4256-abd5-2b562a1a0a2b: 6 new matches, total now 157
# 21db2a98-1b87-41a2-8409-887c9b510326 offset 0: 12 fetched, 8 new matches added
# 21db2a98-1b87-41a2-8409-887c9b510326: 8 new matches, total now 398
# d4b76490-aa5b-4740-9f2c-f728e576b7c4 offset 0: 1 fetched, 1 new matches added
# d4b76490-aa5b-4740-9f2c-f728e576b7c4: 1 new matches, total now 79
# 72732f5c-19e1-415a-a6e0-a1638daaf631: 0 new matches, total now 66
# f1901d5b-419b-40ad-90c4-adca109c0618 offset 0: 1 fetched, 1 new matches added
# f1901d5b-419b-40ad-90c4-adca109c0618: 1 new matches, total now 147
# 2eec4f80-a7f0-45cb-b3f2-5b8ca0d9b6d0: 0 new matches, total now 182
# 5a4e258d-c912-46b6-94f1-984d59150f82 offset 0: 1 fetched, 1 new matches added
# 5a4e258d-c912-46b6-94f1-984d59150f82: 1 new matches, total now 97
# 717e53e8-12a3-441d-b071-fc254eec2421: 0 new matches, total now 33
# abc4f3bf-ae13-4176-90c5-f317caf72d74 offset 0: 1 fetched, 1 new matches added
# abc4f3bf-ae13-4176-90c5-f317caf72d74: 1 new matches, total now 63
# 8e0e7f67-82f6-464a-a262-7687390c8681: 0 new matches, total now 3
# b0f5f4db-9b67-4cdd-b5b2-f278fbe98a44 offset 0: 1 fetched, 1 new matches added
# b0f5f4db-9b67-4cdd-b5b2-f278fbe98a44: 1 new matches, total now 76
# 0db726b2-a051-4181-8c29-1c6f3d13fd2c offset 0: 7 fetched, 7 new matches added
# 0db726b2-a051-4181-8c29-1c6f3d13fd2c: 7 new matches, total now 179
# f08205f4-8e01-4b81-b15e-363ba2cd400e offset 0: 2 fetched, 2 new matches added
# f08205f4-8e01-4b81-b15e-363ba2cd400e: 2 new matches, total now 191
# e182052b-59d1-4a22-b55d-ea71206895f5 offset 0: 3 fetched, 3 new matches added
# e182052b-59d1-4a22-b55d-ea71206895f5: 3 new matches, total now 219
# 99843439-93a8-4d0d-9647-88b19dd43a0a offset 0: 5 fetched, 5 new matches added
# 99843439-93a8-4d0d-9647-88b19dd43a0a: 5 new matches, total now 155
# 632ef4b7-f2f6-4ccf-a090-e59ab490b8cb offset 0: 3 fetched, 2 new matches added
# 632ef4b7-f2f6-4ccf-a090-e59ab490b8cb: 2 new matches, total now 80
# 6fb6d281-65c8-4001-bfd6-9e65b56257c3 offset 0: 3 fetched, 3 new matches added
# 6fb6d281-65c8-4001-bfd6-9e65b56257c3: 3 new matches, total now 214
# 189a010e-9bf6-408e-b35a-33075ef27bcf offset 0: 9 fetched, 9 new matches added
# 189a010e-9bf6-408e-b35a-33075ef27bcf: 9 new matches, total now 362
# 88fef95a-77f1-4cc8-bf54-4f04af3ad80c offset 0: 4 fetched, 4 new matches added
# 88fef95a-77f1-4cc8-bf54-4f04af3ad80c: 4 new matches, total now 52
# 96b09d1d-9078-4dc6-a4cb-28992e08db02 offset 0: 5 fetched, 5 new matches added
# 96b09d1d-9078-4dc6-a4cb-28992e08db02: 5 new matches, total now 287
# 0064f9a0-9498-4d28-973d-b198e6393979 offset 0: 2 fetched, 2 new matches added
# 0064f9a0-9498-4d28-973d-b198e6393979: 2 new matches, total now 50
# e2c48863-bbe2-4ac2-9f82-d63fa4af8556 offset 0: 1 fetched, 1 new matches added
# e2c48863-bbe2-4ac2-9f82-d63fa4af8556: 1 new matches, total now 90
# 06dc7f03-7824-4765-b299-1130af1dcb5c offset 0: 2 fetched, 2 new matches added
# 06dc7f03-7824-4765-b299-1130af1dcb5c: 2 new matches, total now 40
# 3530ede7-a34e-43e4-bcda-3645b471b5e6: 0 new matches, total now 114
# f2fc939c-b032-45df-8d02-26041a7192b4 offset 0: 10 fetched, 10 new matches added
# f2fc939c-b032-45df-8d02-26041a7192b4: 10 new matches, total now 248
# 6b05098e-b46f-4d25-a45b-bd724bcc25d8: 0 new matches, total now 13
# 377bd0d9-3ad3-4d47-a412-d59914405702 offset 0: 4 fetched, 4 new matches added
# 377bd0d9-3ad3-4d47-a412-d59914405702: 4 new matches, total now 312
# 85bba464-4175-48de-aac0-10165b6fb485 offset 0: 2 fetched, 2 new matches added
# 85bba464-4175-48de-aac0-10165b6fb485: 2 new matches, total now 98
# 1f63e62e-0dff-41cc-ac01-d92e434ed749 offset 0: 1 fetched, 1 new matches added
# 1f63e62e-0dff-41cc-ac01-d92e434ed749: 1 new matches, total now 41
# 2619cded-70f7-4830-816d-54e9340bda55 offset 0: 3 fetched, 3 new matches added
# 2619cded-70f7-4830-816d-54e9340bda55: 3 new matches, total now 125
# e37dae40-3946-464c-96f8-a0a88b666e9e offset 0: 2 fetched, 2 new matches added
# e37dae40-3946-464c-96f8-a0a88b666e9e: 2 new matches, total now 139
# d56f1656-21be-42b2-8978-d9121b9433e2 offset 0: 1 fetched, 1 new matches added
# d56f1656-21be-42b2-8978-d9121b9433e2: 1 new matches, total now 159
# 33663617-5c34-448f-976b-f3f5004bd658 offset 0: 2 fetched, 2 new matches added
# 33663617-5c34-448f-976b-f3f5004bd658: 2 new matches, total now 131
# bb008748-586c-448c-b1d7-37ba7480033b offset 0: 1 fetched, 1 new matches added
# bb008748-586c-448c-b1d7-37ba7480033b: 1 new matches, total now 89
# acac5d38-6f66-4e2c-8cbf-5c0c45babad7 offset 0: 3 fetched, 3 new matches added
# acac5d38-6f66-4e2c-8cbf-5c0c45babad7: 3 new matches, total now 194
# 0616250b-5329-44c0-b72a-80dbac55b01c offset 0: 4 fetched, 4 new matches added
# 0616250b-5329-44c0-b72a-80dbac55b01c: 4 new matches, total now 295
# 9271ae9d-ab63-44b3-860e-ba2d3c4421a7 offset 0: 5 fetched, 5 new matches added
# 9271ae9d-ab63-44b3-860e-ba2d3c4421a7: 5 new matches, total now 246
# 34df74fc-2b3a-4b02-9d93-3e30b4413a35 offset 0: 1 fetched, 1 new matches added
# 34df74fc-2b3a-4b02-9d93-3e30b4413a35: 1 new matches, total now 87
# cec8aaaf-9fcc-49f2-b2f3-db846901de86 offset 0: 2 fetched, 2 new matches added
# cec8aaaf-9fcc-49f2-b2f3-db846901de86: 2 new matches, total now 44
# 9b45446b-8769-4d46-91d8-73e1c6da7f11 offset 0: 5 fetched, 5 new matches added
# 9b45446b-8769-4d46-91d8-73e1c6da7f11: 5 new matches, total now 138
# 0c3b0a17-f0f6-46fb-a7c9-49ab570a8748: 0 new matches, total now 49
# 3beac6fa-7cb8-4bfb-a75d-278c8ff6c7b1: 0 new matches, total now 73
# 7bc7d1c9-b9c9-45be-8701-876af1175d2a offset 0: 6 fetched, 6 new matches added
# 7bc7d1c9-b9c9-45be-8701-876af1175d2a: 6 new matches, total now 271
# 49a5e8aa-7a82-4d1e-b560-5623f0290873 offset 0: 5 fetched, 5 new matches added
# 49a5e8aa-7a82-4d1e-b560-5623f0290873: 5 new matches, total now 150
# d4e01cf8-4877-4603-97bf-8ebde037acd3 offset 0: 9 fetched, 9 new matches added
# d4e01cf8-4877-4603-97bf-8ebde037acd3: 9 new matches, total now 401
# ac40b9a1-862d-4bf5-b272-b9f49487218f offset 0: 1 fetched, 1 new matches added
# ac40b9a1-862d-4bf5-b272-b9f49487218f: 1 new matches, total now 44
# c65a0796-ab36-4f24-8242-3d045b84b123: 0 new matches, total now 88
# 4f186f9f-3d6b-48f2-8bd2-4444ddaba917: 0 new matches, total now 245
# e9ca8e5e-90c4-4a44-8222-c054862c21db offset 0: 3 fetched, 3 new matches added
# e9ca8e5e-90c4-4a44-8222-c054862c21db: 3 new matches, total now 125
# 6413ac75-8e48-45da-a4e3-c8e597942211 offset 0: 4 fetched, 4 new matches added
# 6413ac75-8e48-45da-a4e3-c8e597942211: 4 new matches, total now 54
# 4d84e0f3-b26f-4a84-a6f8-819e2706edae offset 0: 4 fetched, 4 new matches added
# 4d84e0f3-b26f-4a84-a6f8-819e2706edae: 4 new matches, total now 166
# 452ef317-28c3-4b9e-9430-3a867fe4e2fb offset 0: 6 fetched, 6 new matches added
# 452ef317-28c3-4b9e-9430-3a867fe4e2fb: 6 new matches, total now 279
# 88d4909c-bcb5-4da3-aae9-700a3eccbdb2 offset 0: 2 fetched, 2 new matches added
# 88d4909c-bcb5-4da3-aae9-700a3eccbdb2: 2 new matches, total now 127
# c4cd706d-2fdd-4bf0-8e36-44c3a9a1d45a offset 0: 2 fetched, 2 new matches added
# c4cd706d-2fdd-4bf0-8e36-44c3a9a1d45a: 2 new matches, total now 13
# 53b1c734-d57e-4c11-9dcc-0cc27c6a6439 offset 0: 2 fetched, 2 new matches added
# 53b1c734-d57e-4c11-9dcc-0cc27c6a6439: 2 new matches, total now 156
# f88dc10f-adbc-407b-a01f-dc5480527b2c offset 0: 1 fetched, 1 new matches added
# f88dc10f-adbc-407b-a01f-dc5480527b2c: 1 new matches, total now 222
# df16ab91-49fd-4ffe-a2c2-bb97332eb0ec offset 0: 8 fetched, 8 new matches added
# df16ab91-49fd-4ffe-a2c2-bb97332eb0ec: 8 new matches, total now 483
# 610c5926-df79-42f6-8cbf-9ec15f80c82e: 0 new matches, total now 10
# ed5aabf9-9c09-4fca-8b55-3c096a49a8d7 offset 0: 3 fetched, 3 new matches added
# ed5aabf9-9c09-4fca-8b55-3c096a49a8d7: 3 new matches, total now 85
# b92cd268-9f31-4532-a561-43f24b5adf80: 0 new matches, total now 38
# e52567dc-b5e5-4a3e-ba7e-7967de5ea460 offset 0: 1 fetched, 1 new matches added
# e52567dc-b5e5-4a3e-ba7e-7967de5ea460: 1 new matches, total now 48
# ce5cd047-799b-4d34-8046-567d29d84fee offset 0: 9 fetched, 9 new matches added
# ce5cd047-799b-4d34-8046-567d29d84fee: 9 new matches, total now 189
# a4e2cc20-5faa-414b-8245-530773b3648e offset 0: 1 fetched, 1 new matches added
# a4e2cc20-5faa-414b-8245-530773b3648e: 1 new matches, total now 93
# bf1a5b3c-1d2b-45a3-b183-e5259155fd87: 0 new matches, total now 91
# 1ce3f556-a6a9-4102-b2ad-0aa1ebd102c1 offset 0: 2 fetched, 2 new matches added
# 1ce3f556-a6a9-4102-b2ad-0aa1ebd102c1: 2 new matches, total now 98
# 33101556-0aa6-44e0-8e6e-b485d9bcb159: 0 new matches, total now 44
# 1c957154-1451-4f82-be69-535a4778b36b offset 0: 2 fetched, 2 new matches added
# 1c957154-1451-4f82-be69-535a4778b36b: 2 new matches, total now 152
# ea737883-92d0-43de-91c8-5a9d72f47bce offset 0: 6 fetched, 5 new matches added
# ea737883-92d0-43de-91c8-5a9d72f47bce: 5 new matches, total now 183
# ✅ All captain matches updated in D:\Data project\Faceit dashboard\FaceitApi_Dataproject\data\Season 54\EU\Regular\all_captain_matches.json
# 🎯 Total new matches fetched this run: 3384

# %%
# with open(r"data\Season 54\EU\Regular\all_captain_matches.json", "r", encoding="utf-8") as f:
#     all_captain_matches = json.load(f)

# %%
rows = []
for player_id, matches in all_captain_matches.items():
    for match_id, match_info in matches.items():
        rows.append({
            "match_id": match_id,
            "competition_id": match_info.get("competition_id"),
            "match_day": match_info.get("started_at"),
            "faction1_team_id" : match_info.get("faction1_team_id"),
            "faction2_team_id": match_info.get("faction2_team_id"),
            "winner": match_info.get("winner"),
        })

# Convert to DataFrame
all_captain_matches_df = pd.DataFrame(rows)

# Optional: convert started_at to datetime
all_captain_matches_df["match_day"] = pd.to_datetime(all_captain_matches_df["match_day"], unit="s")

# %%
filtered_captain_matches_df = all_captain_matches_df[all_captain_matches_df['competition_id'].isin(championship_map)]
filtered_captain_matches_df = filtered_captain_matches_df.drop_duplicates(subset=['match_id'], keep='first')
filtered_captain_matches_df['winner_id'] = np.where(
    filtered_captain_matches_df['winner'] == 'faction1',
    filtered_captain_matches_df['faction1_team_id'],
    filtered_captain_matches_df['faction2_team_id']
)
filtered_captain_matches_df['loser_id'] = np.where(
    filtered_captain_matches_df['winner'] == 'faction1',
    filtered_captain_matches_df['faction2_team_id'],
    filtered_captain_matches_df['faction1_team_id']
)

filtered_captain_matches_df = filtered_captain_matches_df.drop(columns={'faction1_team_id','faction2_team_id','winner'})
filtered_captain_matches_df = filtered_captain_matches_df.reset_index(drop=True)

# %%
filtered_captain_matches_df
# Out:
#                                     match_id  \
# 0     1-f197f4c1-6c52-46f6-b66b-edd2f5830813
# 1     1-8d4a43ae-90a0-48bb-a575-c089699bca24
# 2     1-89b9853e-781a-4ca6-bb34-5ee736e20a50
# 3     1-d606f510-8000-4f18-a438-5712554f4d49
# 4     1-5517b202-c958-4244-8688-d123d637e178
# ...                                      ...
# 7795  1-514ebf59-d0b6-442b-abbf-6a7251f7314f
# 7796  1-4be15fc7-60f2-42e2-bc5a-da19504534cb
# 7797  1-40b28985-c35e-4124-9f2a-30a543d730dd
# 7798  1-b202e7b4-9f28-433f-8043-bcdff80d4048
# 7799  1-d9206de0-f03f-456e-9c56-f466e7de9f46
#
#                             competition_id           match_day  \
# 0     e61be909-1727-4de3-8201-419d89893401 2025-08-18 18:07:19
# 1     e61be909-1727-4de3-8201-419d89893401 2025-08-13 18:41:24
# 2     e61be909-1727-4de3-8201-419d89893401 2025-08-11 18:39:34
# 3     e61be909-1727-4de3-8201-419d89893401 2025-08-10 18:36:18
# 4     e61be909-1727-4de3-8201-419d89893401 2025-08-04 18:39:52
# ...                                    ...                 ...
# 7795  786da1fa-a9b5-4d17-b40e-416588272db4 2025-07-31 05:18:18
# 7796  786da1fa-a9b5-4d17-b40e-416588272db4 2025-07-25 16:52:56
# 7797  4410aa73-9584-4500-a7ca-1504ed6da707 2025-08-12 18:14:10
# 7798  e61be909-1727-4de3-8201-419d89893401 2025-07-23 18:39:19
# 7799  e61be909-1727-4de3-8201-419d89893401 2025-07-23 18:39:51
#
#                                  winner_id  \
# 0     83756527-b019-449f-9660-adc29f01416f
# 1     97f7d131-9ffe-4dde-a8e5-e2dcee2113ea
# 2     cfdfa687-0075-4f23-8129-28eb01b37a2a
# 3     aeff8fa0-734c-45bb-8b9b-f18847d630f6
# 4     cfdfa687-0075-4f23-8129-28eb01b37a2a
# ...                                    ...
# 7795  5f2e9987-a2a3-4901-94cf-8fa9457f307b
# 7796  85322397-fbb0-4cfc-a092-d9fd8a9edb1a
# 7797  b3e21e6e-7e76-4cba-b3af-b65b91833d6c
# 7798  4269aee6-d662-4d1b-80c9-495904bd65ed
# 7799  bdc870bc-c386-4488-9084-6df1ff584794
#
#                                   loser_id
# 0     cfdfa687-0075-4f23-8129-28eb01b37a2a
# 1     cfdfa687-0075-4f23-8129-28eb01b37a2a
# 2     db190109-606c-4845-a773-574dde647db3
# 3     cfdfa687-0075-4f23-8129-28eb01b37a2a
# 4     dc0203c1-9604-4ad0-bdea-644b117609b3
# ...                                    ...
# 7795  85322397-fbb0-4cfc-a092-d9fd8a9edb1a
# 7796                                   bye
# 7797  df862c73-6fc9-4f84-8160-22dd06293fd3
# 7798  7895ce74-408e-421d-b83a-05337ac700d4
# 7799  270c07be-ae43-4628-bc95-e3776f167dee
#
# [7800 rows x 5 columns]

# %%
# Define the path to your stats file
stats_file = Path(r"data\Season 54\EU\Regular\detailed_match_stats.json")

# Load existing stats or start empty
if stats_file.exists():
    with stats_file.open("r", encoding="utf-8") as f:
        all_stats = json.load(f)
else:
    all_stats = {}

# Keep track of already fetched match IDs
existing_match_ids = set(all_stats.keys())

# %%
new_match_ids = filtered_captain_matches_df[
    ~filtered_captain_matches_df["match_id"].isin(existing_match_ids)
]["match_id"].tolist()

print(f"🔹 {len(new_match_ids)} new matches to fetch stats for.")
# Out:
# 🔹 1830 new matches to fetch stats for.

# %% [markdown]
# ### Pull detailed stats of all ESEA matches found

# %%
def fetch_single_match(match_id):
    url = f"https://open.faceit.com/data/v4/matches/{match_id}/stats"
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 404:
            return match_id, None
        response.raise_for_status()
        time.sleep(delay)
        return match_id, response.json()
    except requests.exceptions.RequestException:
        return match_id, None

# --------------------------
# 6. Threaded fetching
# --------------------------
if new_match_ids:
    with ThreadPoolExecutor(max_workers=max_threads) as executor:
        futures = {executor.submit(fetch_single_match, mid): mid for mid in new_match_ids}
        for i, future in enumerate(as_completed(futures), start=1):
            match_id, data = future.result()
            if data is not None:
                all_stats[match_id] = data
                print(f"[{i}/{len(new_match_ids)}] {match_id} fetched ✅")
            else:
                print(f"[{i}/{len(new_match_ids)}] {match_id} has no stats ❌")
else:
    print("No new matches to fetch.")

# --------------------------
# 7. Save updated stats
# --------------------------
with stats_file.open("w", encoding="utf-8") as f:
    json.dump(all_stats, f, indent=2)

print(f"\n✅ Done! Total stored matches in detailed_match_stats.json: {len(all_stats)}")
# Out:
# [1/1830] 1-07ea9bcc-4278-4ace-b358-bea44d0d5b69 has no stats ❌
# [2/1830] 1-1ad2265b-87df-422d-89a1-64085b55049f has no stats ❌
# [3/1830] 1-6ac0fa5a-8485-4263-9d91-4db12aebad94 has no stats ❌
# [4/1830] 1-42fb9f0a-bc5c-4012-9a07-b283fdbe1f9a has no stats ❌
# [5/1830] 1-697862c4-4cfa-4e46-96e2-1e251d0133c5 has no stats ❌
# [6/1830] 1-45bef5ed-c015-4b68-813f-8640e2d52931 has no stats ❌
# [7/1830] 1-1706fa4d-8768-4779-87c7-6d6e2205fd90 has no stats ❌
# [8/1830] 1-74a39db1-537d-4e42-bc65-9616cdda7b49 has no stats ❌
# [9/1830] 1-f85b2bd4-ceaa-43c3-90d6-13fa2dfb9297 has no stats ❌
# [10/1830] 1-26642931-ac9b-49ce-b9bc-bf2b594e6d08 has no stats ❌
# [11/1830] 1-b82f94d7-02c3-497a-b3fb-95ff20d896a9 has no stats ❌
# [12/1830] 1-73b2dbcb-5b00-469f-b7c9-2c7010479172 has no stats ❌
# [13/1830] 1-6cea49c9-c7fa-4a7b-a7cb-3d95770dbbdb has no stats ❌
# [14/1830] 1-57bed81b-2e88-480d-b9fa-ffcdd5baee9e has no stats ❌
# [15/1830] 1-b1dd2bf6-7a47-4e03-8dab-15da95abd044 has no stats ❌
# [16/1830] 1-23d51cb1-c0d3-414d-9165-2a688fe9a003 has no stats ❌
# [17/1830] 1-d7d325ed-9fc4-477a-953d-1539b212f919 fetched ✅
# [18/1830] 1-cebbfa15-f5ff-4321-9c88-fe80b0f51f06 has no stats ❌
# [19/1830] 1-bfa4ab77-1ba9-4240-8cff-f48c1cb0e85e has no stats ❌
# [20/1830] 1-972b536b-7e52-4202-b200-ec6143a97949 has no stats ❌
# [21/1830] 1-609555ca-ffa5-4100-b22b-a27c962e3dae has no stats ❌
# [1815/1830] 1-7e2d7b0d-fa45-40c9-81bc-2681646a73c9 has no stats ❌
# [1816/1830] 1-24fbe770-db53-415f-8ca4-2bdfe36863fb has no stats ❌
# [1817/1830] 1-b1ced890-ae7e-48be-ad29-1be1ae958b84 has no stats ❌
# [1818/1830] 1-2cc11b24-792f-4399-af69-717d36aaf3e4 has no stats ❌
# [1819/1830] 1-ce26ef76-4a19-4d3b-abcb-525b0f0f68e5 has no stats ❌
# [1820/1830] 1-3c1af317-b8be-47ea-8ce6-577c56eff858 has no stats ❌
# [1821/1830] 1-1e36d7cb-cc52-401a-a885-53368982842c has no stats ❌
# [1822/1830] 1-f868a2c1-126a-4b9d-b2c2-e312130023ab has no stats ❌
# [1823/1830] 1-fc911f44-e819-41f7-b0af-6453eb12ea1e has no stats ❌
# [1824/1830] 1-d0416492-a630-4c98-aefe-555e58c78463 has no stats ❌
# [1825/1830] 1-759b35e2-fdf4-4923-b5aa-9229fdb5a4bc has no stats ❌
# [1826/1830] 1-79a7475c-d85b-4c5b-84bb-dfc0a2a476d5 has no stats ❌
# [1827/1830] 1-e8f22dd7-f1fa-4a9d-b81f-d3a1a2f895a3 has no stats ❌
# [1828/1830] 1-29bf10f7-0675-42f8-9133-b5bee41373ad has no stats ❌
# [1829/1830] 1-514ebf59-d0b6-442b-abbf-6a7251f7314f has no stats ❌
# [1830/1830] 1-4be15fc7-60f2-42e2-bc5a-da19504534cb has no stats ❌
#
# ✅ Done! Total stored matches in detailed_match_stats.json: 6277

# %%
team_ids = set()  # set pour éviter les doublons

for match_id, match_data in all_stats.items():
    rounds = match_data.get('rounds', [])
    for round_data in rounds:
        teams = round_data.get('teams', [])
        for team in teams:
            team_id = team.get('team_id')
            if team_id:
                team_ids.add(team_id)

team_ids = list(team_ids)

# %% [markdown]
# ### Pull details of each team involved in ESEA matches

# %%
team_ids_to_fetch = [team["team_id"] for team in team_list if team["team_id"]]

def fetch_team_details(team_ids, headers, team_file="team_details.json", delay=0.3, max_threads=5):
    team_path = Path(team_file)

    # Load existing data if present
    if team_path.exists():
        with team_path.open("r", encoding="utf-8") as f:
            all_teams = json.load(f)
    else:
        all_teams = {}

    # Filter team_ids that haven't been fetched yet
    to_fetch = [tid for tid in team_ids if tid not in all_teams]
    print(f"🔍 {len(to_fetch)} new teams to fetch among {len(team_ids)} total.\n")

    def fetch_single_team(team_id):
        url = f"https://open.faceit.com/data/v4/teams/{team_id}"
        try:
            response = requests.get(url, headers=headers)
            if response.status_code == 404:
                print(f"{team_id} → Team not found (404) ❌")
                return team_id, None

            response.raise_for_status()
            time.sleep(delay)
            return team_id, response.json()
        except requests.exceptions.RequestException as e:
            print(f"Error fetching {team_id} ❌ : {e}")
            return team_id, None

    # Threaded fetching
    if to_fetch:
        with ThreadPoolExecutor(max_workers=max_threads) as executor:
            futures = {executor.submit(fetch_single_team, tid): tid for tid in to_fetch}
            for i, future in enumerate(as_completed(futures), start=1):
                team_id, data = future.result()
                all_teams[team_id] = data
                status = "fetched ✅" if data else "failed ❌"
                print(f"[{i}/{len(to_fetch)}] {team_id} {status}")
    else:
        print("No new teams to fetch.")

    # Save updated teams
    with team_path.open("w", encoding="utf-8") as f:
        json.dump(all_teams, f, indent=2)

    print(f"\n✅ Done! Total teams stored: {len(all_teams)}")
    return all_teams

all_teams_data = fetch_team_details(team_ids_to_fetch, headers, team_file="team_details.json", delay=delay)
# Out:
# 🔍 0 new teams to fetch among 1339 total.
#
# No new teams to fetch.
#
# ✅ Done! Total teams stored: 1340

# %% [markdown]
# ## Tables building

# %% [markdown]
# ### dim_championship table

# %%
championship_details_list = []

for data in master_matches:  # juste itérer sur la liste
    if data is None:
        continue  # skip entries with no data

    row = {
        'competition_id': data.get('competition_id'),
        'competition_name': data.get('competition_name'),
        'competition_type': data.get('competition_type'),
        'region': data.get('region'),
        'started_at': data.get('finished_at'), #on utilise la valeur de finished_at comme jour de match car si le match a été dodge il n'y a pas de start_date
    }
    championship_details_list.append(row)

dim_championships = pd.DataFrame(championship_details_list)

# %%
dim_championships['started_at'] = pd.to_datetime(dim_championships['started_at'], unit='s', utc=True).dt.date

# %%
dim_championships[['organizer','season','region','division','sub_region','state','state2','state3']] = dim_championships['competition_name'].str.split(' ',expand=True)
dim_championships['state'] = dim_championships['state2'] + ' ' + dim_championships['state3']
dim_championships.drop(columns=['state2', 'state3'], inplace=True)

# %%
dim_championships = dim_championships.groupby(["competition_id"]).agg({
    "organizer": "first", 
    "competition_type": "first", 
    'region':'first',
    'sub_region':'first',
    "season": "first",       
    "division": "first",               
    "state": "first",
    "started_at" :"first",
}).reset_index()

# %%
dim_championships
# Out:
#                          competition_id organizer competition_type region  \
# 0  0ce757ef-9bad-4afa-bbce-58d647824222      ESEA     championship     EU
# 1  3cd81a7e-ed93-43ba-be08-2a1ee7ad7237      ESEA     championship     EU
# 2  4410aa73-9584-4500-a7ca-1504ed6da707      ESEA     championship     EU
# 3  786da1fa-a9b5-4d17-b40e-416588272db4      ESEA     championship     EU
# 4  bd7957b3-1114-435f-af43-22645a508cc0      ESEA     championship     EU
# 5  e61be909-1727-4de3-8201-419d89893401      ESEA     championship     EU
# 6  f62c4c75-f620-40a2-bef8-0be2cb85d2d3      ESEA     championship     EU
#
#   sub_region season      division           state  started_at
# 0    Central    S54         Open9  Regular Season  2025-08-08
# 1    Central    S54       Open1-8  Regular Season  2025-08-10
# 2    Central    S54  Intermediate  Regular Season  2025-08-11
# 3    Central    S54      Advanced  Regular Season  2025-08-11
# 4    Central    S54          Main  Regular Season  2025-08-08
# 5    Central    S54         Entry  Regular Season  2025-08-08
# 6    Central    S54        Open10  Regular Season  2025-08-08

# %% [markdown]
# ### dim_teams and dim_players tables

# %%
team_details_list = []

for team_ids, team_data in all_teams_data.items():
    if team_data is None:
        continue  # 👈 Skip entries with no data

    row = {
        'team_id': team_data.get('team_id'),
        'team_nickname': team_data.get('nickname'),
        'team_name': team_data.get('name'),
        'team_avatar': team_data.get('avatar'),
        'team_faceit_url': team_data.get('faceit_url'),
    }
    team_details_list.append(row)

dim_teams = pd.DataFrame(team_details_list)
dim_teams = dim_teams.drop_duplicates(subset=['team_id'], keep='last')
dim_teams['team_faceit_url'] = dim_teams['team_faceit_url'].str.replace('/{lang}','')

# %%
#get lis of teams & players from championship request
players_details_list = []

for match_id, match_data in all_stats.items():
    for round_data in match_data['rounds']:
        for team in round_data['teams']:
            team_id = team.get("team_id")
            for player in team["players"]:
                player_id = player["player_id"]
                nickname = player["nickname"]

                row = {
                    "player_id": player_id,
                    "team_id": team_id,
                    "player_name": nickname
                }

                row.update()
                players_details_list.append(row)

players_matches = pd.DataFrame(players_details_list)
players_matches = players_matches.drop_duplicates(subset=['player_id'], keep='last')

# %%
#enrich with detail of players from team_detail request
players_details_list = []

for team_id, team_data in all_teams_data.items():
    if team_data is None or 'members' not in team_data:
        continue 

    for member in team_data['members']:
        row = {
            'player_id': member.get('user_id'),
            'player_country': member.get('country'),
            'player_faceit_url': member.get('faceit_url'),
            'player_avatar' : member.get('avatar')
        }
        players_details_list.append(row)

# Create DataFrame
players_team_details = pd.DataFrame(players_details_list)
players_team_details = players_team_details.drop_duplicates(subset=['player_id'], keep='last')

# %%
dim_players = pd.merge(players_matches, players_team_details, on='player_id',how='left')
dim_players['player_faceit_url'] = dim_players['player_faceit_url'].str.replace('/{lang}','')

# %%
dim_players
# Out:
#                                  player_id  \
# 0     b89a3885-c9be-4dae-a593-1ad03bd48784
# 1     117cb564-1753-47c0-8a3c-7f00f2e17534
# 2     d2a9afea-2411-49c2-9d7b-6283dcccef40
# 3     b065a172-1af3-4ce8-9b1b-6e6a4e0297cc
# 4     9f95b1c2-cbd7-472a-9189-e0adfea5097a
# ...                                    ...
# 8295  11022d06-2cf4-4221-a0fb-083971be2ab6
# 8296  ea228795-e3d9-4fb0-b2c4-48ab3aa34976
# 8297  3af5d1af-75db-4cc2-aa8b-76b1f1b76af8
# 8298  492a0844-1694-43a1-b318-a79898a498e5
# 8299  5c132ee7-9463-4456-beac-1c0aa1622728
#
#                                    team_id player_name player_country  \
# 0     934a2bd0-fa66-4c02-ac92-00f742e7ec55     wolterz             ru
# 1     1b637421-544a-4c74-9b70-e5ee5cf541f9       -FaaT             pl
# 2     df862c73-6fc9-4f84-8160-22dd06293fd3     shepzor             ru
# 3     45f3397b-4dae-426c-b7ec-5c743ab13373     Dante12            NaN
# 4     b7d71a56-69f7-409b-ac41-d1113f659153     johny01             hu
# ...                                    ...         ...            ...
# 8295  f69fbdff-83f7-4ab2-aa99-a1c8742340ec      Flompy             tr
# 8296  f69fbdff-83f7-4ab2-aa99-a1c8742340ec    singvayn             TR
# 8297  f69fbdff-83f7-4ab2-aa99-a1c8742340ec  xEternaLxx             tr
# 8298  f69fbdff-83f7-4ab2-aa99-a1c8742340ec     -D1KUBA             pl
# 8299  f69fbdff-83f7-4ab2-aa99-a1c8742340ec       deaNz            NaN
#
#                               player_faceit_url  \
# 0        https://www.faceit.com/players/wolterz
# 1          https://www.faceit.com/players/-FaaT
# 2        https://www.faceit.com/players/shepzor
# 3                                           NaN
# 4        https://www.faceit.com/players/johny01
# ...                                         ...
# 8295      https://www.faceit.com/players/Flompy
# 8296    https://www.faceit.com/players/singvayn
# 8297  https://www.faceit.com/players/xEternaLxx
# 8298     https://www.faceit.com/players/-D1KUBA
# 8299                                        NaN
#
#                                           player_avatar
# 0     https://distribution.faceit-cdn.net/images/93f...
# 1     https://distribution.faceit-cdn.net/images/1a9...
# 2     https://distribution.faceit-cdn.net/images/62c...
# 3                                                   NaN
# 4     https://distribution.faceit-cdn.net/images/12a...
# ...                                                 ...
# 8295  https://distribution.faceit-cdn.net/images/938...
# 8296  https://distribution.faceit-cdn.net/images/ce9...
# 8297  https://distribution.faceit-cdn.net/images/6b2...
# 8298  https://distribution.faceit-cdn.net/images/91b...
# 8299                                                NaN
#
# [8300 rows x 6 columns]

# %% [markdown]
# ### dim_matches table

# %% [markdown]
# The idea is to have a composite key with the combination of match_id and match_round being unique :
#
# - match id being the whole match (either its a Bo1, Bo3 or Bo5)
# - match_round being the id of the map played (1 if a single map is played and then increase up to 5 for Bo5)

# %%
dim_match_list = []

for match_id, match_data in all_stats.items():
    for round_data in match_data['rounds']:
        for team in round_data['teams']:

            # Get both teams once per match
            teams = round_data['teams']  # Safe because you've pre-filtered

            for round_data in match_data['rounds']:
                round_stats = round_data['round_stats']
                winner_id = round_stats["Winner"]
                
                dim_match_list.append({
                    "match_id": match_id,
                    "match_round": round_data["match_round"],
                    "format": f"bo{round_data['best_of']}",
                    "map": round_stats["Map"],
                    "total_rounds_played": round_stats["Rounds"]
                })

dim_matches_matchquery = pd.DataFrame(dim_match_list)

# %%
dim_matches_matchquery
# Out:
#                                      match_id match_round format         map  \
# 0      1-74860e59-e961-4a1c-868c-55ef7d3215b8           1    bo1    de_dust2
# 1      1-74860e59-e961-4a1c-868c-55ef7d3215b8           1    bo1    de_dust2
# 2      1-14e4f8cb-ca01-47f8-aee1-19136f852ea4           1    bo1     de_nuke
# 3      1-14e4f8cb-ca01-47f8-aee1-19136f852ea4           1    bo1     de_nuke
# 4      1-0b1fb845-4c11-42af-8026-743757ba84ea           1    bo1   de_anubis
# ...                                       ...         ...    ...         ...
# 12560  1-c1613561-333c-4f82-aa91-08537895675a           1    bo1     de_nuke
# 12561  1-8d62e81b-58d0-420a-8e2b-a4273e99423b           1    bo1  de_ancient
# 12562  1-8d62e81b-58d0-420a-8e2b-a4273e99423b           1    bo1  de_ancient
# 12563  1-5fd2c46e-07b9-40b0-a86d-0f7e0bcf8898           1    bo1  de_ancient
# 12564  1-5fd2c46e-07b9-40b0-a86d-0f7e0bcf8898           1    bo1  de_ancient
#
#       total_rounds_played
# 0                      12
# 1                      12
# 2                      23
# 3                      23
# 4                      30
# ...                   ...
# 12560                  22
# 12561                  29
# 12562                  29
# 12563                  17
# 12564                  17
#
# [12565 rows x 5 columns]

# %%
# dim_matches = pd.merge(dim_matches_champ_query[['competition_id','match_id','match_day']], dim_matches_matchquery, on='match_id')
dim_matches = pd.merge(filtered_captain_matches_df, dim_matches_matchquery, on='match_id',how='left')
dim_matches = dim_matches.drop_duplicates(subset=["match_id", "competition_id", "match_day"])

# define format and match_round (working with bo1 and bo3)
dim_matches["round_count"] = dim_matches.groupby(["match_id", "competition_id"])["match_id"].transform("count")
dim_matches["match_round"] = dim_matches.groupby(["match_id", "competition_id"])["match_day"].rank(method="first").astype(int).astype(str)
dim_matches["format"] = dim_matches["round_count"].apply(lambda x: "bo1" if x == 1 else "bo3")
dim_matches = dim_matches.drop(columns=["round_count"])

# %%
dim_matches
# Out:
#                                      match_id  \
# 0      1-f197f4c1-6c52-46f6-b66b-edd2f5830813
# 2      1-8d4a43ae-90a0-48bb-a575-c089699bca24
# 4      1-89b9853e-781a-4ca6-bb34-5ee736e20a50
# 6      1-d606f510-8000-4f18-a438-5712554f4d49
# 8      1-5517b202-c958-4244-8688-d123d637e178
# ...                                       ...
# 14080  1-514ebf59-d0b6-442b-abbf-6a7251f7314f
# 14081  1-4be15fc7-60f2-42e2-bc5a-da19504534cb
# 14082  1-40b28985-c35e-4124-9f2a-30a543d730dd
# 14084  1-b202e7b4-9f28-433f-8043-bcdff80d4048
# 14086  1-d9206de0-f03f-456e-9c56-f466e7de9f46
#
#                              competition_id           match_day  \
# 0      e61be909-1727-4de3-8201-419d89893401 2025-08-18 18:07:19
# 2      e61be909-1727-4de3-8201-419d89893401 2025-08-13 18:41:24
# 4      e61be909-1727-4de3-8201-419d89893401 2025-08-11 18:39:34
# 6      e61be909-1727-4de3-8201-419d89893401 2025-08-10 18:36:18
# 8      e61be909-1727-4de3-8201-419d89893401 2025-08-04 18:39:52
# ...                                     ...                 ...
# 14080  786da1fa-a9b5-4d17-b40e-416588272db4 2025-07-31 05:18:18
# 14081  786da1fa-a9b5-4d17-b40e-416588272db4 2025-07-25 16:52:56
# 14082  4410aa73-9584-4500-a7ca-1504ed6da707 2025-08-12 18:14:10
# 14084  e61be909-1727-4de3-8201-419d89893401 2025-07-23 18:39:19
# 14086  e61be909-1727-4de3-8201-419d89893401 2025-07-23 18:39:51
#
#                                   winner_id  \
# 0      83756527-b019-449f-9660-adc29f01416f
# 2      97f7d131-9ffe-4dde-a8e5-e2dcee2113ea
# 4      cfdfa687-0075-4f23-8129-28eb01b37a2a
# 6      aeff8fa0-734c-45bb-8b9b-f18847d630f6
# 8      cfdfa687-0075-4f23-8129-28eb01b37a2a
# ...                                     ...
# 14080  5f2e9987-a2a3-4901-94cf-8fa9457f307b
# 14081  85322397-fbb0-4cfc-a092-d9fd8a9edb1a
# 14082  b3e21e6e-7e76-4cba-b3af-b65b91833d6c
# 14084  4269aee6-d662-4d1b-80c9-495904bd65ed
# 14086  bdc870bc-c386-4488-9084-6df1ff584794
#
#                                    loser_id match_round format          map  \
# 0      cfdfa687-0075-4f23-8129-28eb01b37a2a           1    bo1   de_ancient
# 2      cfdfa687-0075-4f23-8129-28eb01b37a2a           1    bo1  de_overpass
# 4      db190109-606c-4845-a773-574dde647db3           1    bo1    de_mirage
# 6      cfdfa687-0075-4f23-8129-28eb01b37a2a           1    bo1    de_mirage
# 8      dc0203c1-9604-4ad0-bdea-644b117609b3           1    bo1     de_train
# ...                                     ...         ...    ...          ...
# 14080  85322397-fbb0-4cfc-a092-d9fd8a9edb1a           1    bo1          NaN
# 14081                                   bye           1    bo1          NaN
# 14082  df862c73-6fc9-4f84-8160-22dd06293fd3           1    bo1      de_nuke
# 14084  7895ce74-408e-421d-b83a-05337ac700d4           1    bo1   de_ancient
# 14086  270c07be-ae43-4628-bc95-e3776f167dee           1    bo1    de_anubis
#
#       total_rounds_played
# 0                      15
# 2                      16
# 4                      19
# 6                      42
# 8                      30
# ...                   ...
# 14080                 NaN
# 14081                 NaN
# 14082                  22
# 14084                  22
# 14086                  21
#
# [7800 rows x 9 columns]

# %%
column_order=['match_id','match_round','competition_id','match_day','format','map','total_rounds_played','winner_id','loser_id']
dim_matches = dim_matches[column_order]
dim_matches = dim_matches.drop_duplicates(subset=['match_id','match_round'], keep='first')
dim_matches = dim_matches.reset_index(drop=True)

# %%
dim_matches
# Out:
#                                     match_id match_round  \
# 0     1-f197f4c1-6c52-46f6-b66b-edd2f5830813           1
# 1     1-8d4a43ae-90a0-48bb-a575-c089699bca24           1
# 2     1-89b9853e-781a-4ca6-bb34-5ee736e20a50           1
# 3     1-d606f510-8000-4f18-a438-5712554f4d49           1
# 4     1-5517b202-c958-4244-8688-d123d637e178           1
# ...                                      ...         ...
# 7795  1-514ebf59-d0b6-442b-abbf-6a7251f7314f           1
# 7796  1-4be15fc7-60f2-42e2-bc5a-da19504534cb           1
# 7797  1-40b28985-c35e-4124-9f2a-30a543d730dd           1
# 7798  1-b202e7b4-9f28-433f-8043-bcdff80d4048           1
# 7799  1-d9206de0-f03f-456e-9c56-f466e7de9f46           1
#
#                             competition_id           match_day format  \
# 0     e61be909-1727-4de3-8201-419d89893401 2025-08-18 18:07:19    bo1
# 1     e61be909-1727-4de3-8201-419d89893401 2025-08-13 18:41:24    bo1
# 2     e61be909-1727-4de3-8201-419d89893401 2025-08-11 18:39:34    bo1
# 3     e61be909-1727-4de3-8201-419d89893401 2025-08-10 18:36:18    bo1
# 4     e61be909-1727-4de3-8201-419d89893401 2025-08-04 18:39:52    bo1
# ...                                    ...                 ...    ...
# 7795  786da1fa-a9b5-4d17-b40e-416588272db4 2025-07-31 05:18:18    bo1
# 7796  786da1fa-a9b5-4d17-b40e-416588272db4 2025-07-25 16:52:56    bo1
# 7797  4410aa73-9584-4500-a7ca-1504ed6da707 2025-08-12 18:14:10    bo1
# 7798  e61be909-1727-4de3-8201-419d89893401 2025-07-23 18:39:19    bo1
# 7799  e61be909-1727-4de3-8201-419d89893401 2025-07-23 18:39:51    bo1
#
#               map total_rounds_played                             winner_id  \
# 0      de_ancient                  15  83756527-b019-449f-9660-adc29f01416f
# 1     de_overpass                  16  97f7d131-9ffe-4dde-a8e5-e2dcee2113ea
# 2       de_mirage                  19  cfdfa687-0075-4f23-8129-28eb01b37a2a
# 3       de_mirage                  42  aeff8fa0-734c-45bb-8b9b-f18847d630f6
# 4        de_train                  30  cfdfa687-0075-4f23-8129-28eb01b37a2a
# ...           ...                 ...                                   ...
# 7795          NaN                 NaN  5f2e9987-a2a3-4901-94cf-8fa9457f307b
# 7796          NaN                 NaN  85322397-fbb0-4cfc-a092-d9fd8a9edb1a
# 7797      de_nuke                  22  b3e21e6e-7e76-4cba-b3af-b65b91833d6c
# 7798   de_ancient                  22  4269aee6-d662-4d1b-80c9-495904bd65ed
# 7799    de_anubis                  21  bdc870bc-c386-4488-9084-6df1ff584794
#
#                                   loser_id
# 0     cfdfa687-0075-4f23-8129-28eb01b37a2a
# 1     cfdfa687-0075-4f23-8129-28eb01b37a2a
# 2     db190109-606c-4845-a773-574dde647db3
# 3     cfdfa687-0075-4f23-8129-28eb01b37a2a
# 4     dc0203c1-9604-4ad0-bdea-644b117609b3
# ...                                    ...
# 7795  85322397-fbb0-4cfc-a092-d9fd8a9edb1a
# 7796                                   bye
# 7797  df862c73-6fc9-4f84-8160-22dd06293fd3
# 7798  7895ce74-408e-421d-b83a-05337ac700d4
# 7799  270c07be-ae43-4628-bc95-e3776f167dee
#
# [7800 rows x 9 columns]

# %%
dupes = dim_matches[dim_matches.duplicated(subset=["match_id", "match_round"], keep=False)]
print(dupes)
# Out:
# Empty DataFrame
# Columns: [match_id, match_round, competition_id, match_day, format, map, total_rounds_played, winner_id, loser_id]
# Index: []

# %%
dim_matches.dtypes
# Out:
# match_id                       object
# match_round                    object
# competition_id                 object
# match_day              datetime64[ns]
# format                         object
# map                            object
# total_rounds_played            object
# winner_id                      object
# loser_id                       object
# dtype: object

# %% [markdown]
# ### fact_players_stats table

# %%
player_stats_list = []

for match_id, match_data in all_stats.items():
    for round_data in match_data['rounds']:
        map_name = round_data['round_stats'].get('Map')
        winner_id = round_data['round_stats'].get('Winner')

        for team in round_data['teams']:
            team_id = team.get("team_id")
            team_name = team["team_stats"].get("Team")
            team_win = team["team_stats"].get("Team Win")

            for player in team["players"]:
                player_id = player["player_id"]
                nickname = player["nickname"]
                stats = player["player_stats"]

                row = {
                    "match_id": match_id,
                    "match_round": round_data.get("match_round"),
                    "player_id": player_id,
                    "team_id": team_id,
                }

                row.update(stats)
                player_stats_list.append(row)

fact_players_stats = pd.DataFrame(player_stats_list)

# %%
#enrich with competition_id and match_day
fact_players_stats = pd.merge(fact_players_stats, dim_matches[['match_id','competition_id','match_day']], on=['match_id'])

# %%
#correction d'un cas ou les données d'une game sont en doublons, on garde les lignes qui ont les stats les plus importantes, exemple :https://www.faceit.com/fr/cs2/room/1-e4410b46-a6ac-4037-ad35-d7f91f8bf55f/scoreboard
players_stats_sorted = fact_players_stats.sort_values(['match_id', 'player_id', 'Kills'], ascending=[True, True, False])
fact_players_stats = players_stats_sorted.drop_duplicates(subset=['match_id', 'player_id'], keep='first')
#correction d'un bug ou un joueur sur la fiche d'un match mais n'ayant pas joué se retrouve avec des stats a 0 (nouvelle logique de récupération des matchs via captains)
fact_players_stats = fact_players_stats[fact_players_stats['Damage']!= 0]

# %%
fact_players_stats = fact_players_stats.drop(columns={'Result','Headshots %','K/R Ratio','K/D Ratio','Match Entry Rate','Match 1v1 Win Rate','Flash Success Rate per Match','Sniper Kill Rate per Round','Utility Usage per Round','Flashes per Round in a Match','Sniper Kill Rate per Match','Utility Damage per Round in a Match','Utility Damage Success Rate per Match','Utility Successes','Enemies Flashed per Round in a Match','Utility Success Rate per Match','Match Entry Success Rate','Match 1v2 Win Rate','Utility Enemies'})

# %%
fact_players_stats = fact_players_stats.rename(columns={
    'Zeus Kills':'zeus_kills',
    'Utility Count':'utility_count',
    'Double Kills':'double_kills',
    'Flash Successes':'flash_successes',
    'Quadro Kills':'quadro_kills',
    'Entry Count':'entry_count',
    'First Kills':'first_kills',
    'Flash Count':'flash_count',
    'Sniper Kills':'sniper_kills',
    'Damage':'damage',
    'Utility Damage':'utility_damage',
    'Assists':'assists',
    '1v1Count':'count_1v1',
    'Enemies Flashed':'enemies_flashed',
    'Clutch Kills':'clutch_kills',
    'Penta Kills':'ace',
    'MVPs':'mvps',
    'Deaths':'deaths',
    'Entry Wins':'entry_wins',
    'Kills':'kills',
    '1v2Wins':'wins_1v2',
    '1v1Wins':'wins_1v1',
    'Pistol Kills':'pistol_kills',
    'Knife Kills':'knife_kills',
    'ADR':'adr',
    '1v2Count':'count_1v2',
    'Triple Kills':'triple_kills',
    'Headshots':'headshots',
})

# %%
column_order=['match_id', 'match_round','player_id', 'competition_id','team_id','zeus_kills',
'utility_count',
'double_kills',
'flash_successes',
'quadro_kills',
'entry_count',
'first_kills',
'flash_count',
'sniper_kills',
'damage',
'utility_damage',
'assists',
'count_1v1',
'enemies_flashed',
'clutch_kills',
'ace',
'mvps',
'deaths',
'entry_wins',
'kills',
'wins_1v2',
'wins_1v1',
'pistol_kills',
'knife_kills',
'adr',
'count_1v2',
'triple_kills',
'headshots', 
'match_day']
fact_players_stats = fact_players_stats[column_order]

# %%
fact_players_stats.columns
# Out:
# Index(['match_id', 'match_round', 'player_id', 'competition_id', 'team_id',
#        'zeus_kills', 'utility_count', 'double_kills', 'flash_successes',
#        'quadro_kills', 'entry_count', 'first_kills', 'flash_count',
#        'sniper_kills', 'damage', 'utility_damage', 'assists', 'count_1v1',
#        'enemies_flashed', 'clutch_kills', 'ace', 'mvps', 'deaths',
#        'entry_wins', 'kills', 'wins_1v2', 'wins_1v1', 'pistol_kills',
#        'knife_kills', 'adr', 'count_1v2', 'triple_kills', 'headshots',
#        'match_day'],
#       dtype='object')

# %%
exclude_cols = ['match_id','match_round','player_id','competition_id','team_id','match_day']

for col in fact_players_stats.columns:
    if col not in exclude_cols:
        fact_players_stats[col] = pd.to_numeric(fact_players_stats[col], errors="ignore")
# Out:
# C:\Users\Armel\AppData\Local\Temp\ipykernel_16288\4106138510.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   fact_players_stats[col] = pd.to_numeric(fact_players_stats[col], errors="ignore")

# %%
fact_players_stats.dtypes
# Out:
# match_id                   object
# match_round                object
# player_id                  object
# competition_id             object
# team_id                    object
# zeus_kills                  int64
# utility_count               int64
# double_kills                int64
# flash_successes             int64
# quadro_kills                int64
# entry_count                 int64
# first_kills                 int64
# flash_count                 int64
# sniper_kills                int64
# damage                      int64
# utility_damage              int64
# assists                     int64
# count_1v1                   int64
# enemies_flashed             int64
# clutch_kills                int64
# ace                         int64
# mvps                        int64
# deaths                      int64
# entry_wins                  int64
# kills                       int64
# wins_1v2                    int64
# wins_1v1                    int64
# pistol_kills                int64
# knife_kills                 int64
# adr                       float64
# count_1v2                   int64
# triple_kills                int64
# headshots                   int64
# match_day          datetime64[ns]
# dtype: object

# %%
dupes = fact_players_stats[fact_players_stats.duplicated(subset=["match_id", "match_round","player_id"], keep=False)]
print(dupes)
# Out:
# Empty DataFrame
# Columns: [match_id, match_round, player_id, competition_id, team_id, zeus_kills, utility_count, double_kills, flash_successes, quadro_kills, entry_count, first_kills, flash_count, sniper_kills, damage, utility_damage, assists, count_1v1, enemies_flashed, clutch_kills, ace, mvps, deaths, entry_wins, kills, wins_1v2, wins_1v1, pistol_kills, knife_kills, adr, count_1v2, triple_kills, headshots, match_day]
# Index: []
#
# [0 rows x 34 columns]

# %% [markdown]
# ### fact_teams_stats table

# %%
team_stats_list = []

for match_id, match_data in all_stats.items():
    for round_data in match_data['rounds']:
        total_rounds_played = round_data['round_stats'].get('Rounds')

        for team in round_data['teams']:
            team_id = team.get("team_id")
            team_name = team["team_stats"].get("Team")
            team_win = team["team_stats"].get("Team Win")

            row = {
                "match_id": match_id,
                "match_round": round_data.get("match_round"),
                "team_id": team_id,
                "team_win": team_win,
                "total_rounds_played": total_rounds_played
            }

            row.update(team["team_stats"])
            team_stats_list.append(row)

fact_teams_stats = pd.DataFrame(team_stats_list)

# %%
fact_teams_stats.head(2)
# Out:
#                                  match_id match_round  \
# 0  1-74860e59-e961-4a1c-868c-55ef7d3215b8           1
# 1  1-74860e59-e961-4a1c-868c-55ef7d3215b8           1
#
#                                 team_id team_win total_rounds_played  \
# 0  30191a9c-ceb2-4da0-a146-ec375782ac45        0                  12
# 1  f8ac5861-2bb7-4dd1-8378-afa7a9257920        1                  12
#
#   First Half Score        Team Team Win Final Score Team Headshots  \
# 0                1    officers        0           1            3.2
# 1               11  The Toxics        1          11            4.6
#
#   Second Half Score Overtime score
# 0                 0              0
# 1                 0              0

# %%
# Enrich with competition_id and match_day - only merge on match_id because comp_id and match_day doesnt differ depending on match_round
fact_teams_stats = pd.merge(fact_teams_stats, dim_matches[['match_id','competition_id','match_day']], on='match_id')

# %%
fact_teams_stats
# Out:
#                                      match_id match_round  \
# 0      1-74860e59-e961-4a1c-868c-55ef7d3215b8           1
# 1      1-74860e59-e961-4a1c-868c-55ef7d3215b8           1
# 2      1-14e4f8cb-ca01-47f8-aee1-19136f852ea4           1
# 3      1-14e4f8cb-ca01-47f8-aee1-19136f852ea4           1
# 4      1-0b1fb845-4c11-42af-8026-743757ba84ea           1
# ...                                       ...         ...
# 12552  1-c1613561-333c-4f82-aa91-08537895675a           1
# 12553  1-8d62e81b-58d0-420a-8e2b-a4273e99423b           1
# 12554  1-8d62e81b-58d0-420a-8e2b-a4273e99423b           1
# 12555  1-5fd2c46e-07b9-40b0-a86d-0f7e0bcf8898           1
# 12556  1-5fd2c46e-07b9-40b0-a86d-0f7e0bcf8898           1
#
#                                     team_id team_win total_rounds_played  \
# 0      30191a9c-ceb2-4da0-a146-ec375782ac45        0                  12
# 1      f8ac5861-2bb7-4dd1-8378-afa7a9257920        1                  12
# 2      6d406cd9-c6a2-4c0d-aa9d-45dfa5812460        0                  23
# 3      36ef04e5-fdbe-43bc-b204-3c6d771dca4e        1                  23
# 4      aa598c46-986e-4f63-b06e-b01099a05c37        1                  30
# ...                                     ...      ...                 ...
# 12552  3829366a-38cd-4153-beb6-9b5aef1c3fe7        1                  22
# 12553  5e89b75e-d947-42fa-ba7f-88b17106f947        0                  29
# 12554  974141f2-78a9-46e8-bb93-94d46f5d5045        1                  29
# 12555  8197aa39-3f39-4920-8116-fb908ba388f7        0                  17
# 12556  f69fbdff-83f7-4ab2-aa99-a1c8742340ec        1                  17
#
#       First Half Score            Team Team Win Final Score Team Headshots  \
# 0                    1        officers        0           1            3.2
# 1                   11      The Toxics        1          11            4.6
# 2                    7       5PellMans        0          10            8.6
# 3                    5          WHYNOT        1          13              8
# 4                    6            Tiim        1          16              9
# ...                ...             ...      ...         ...            ...
# 12552                4  FAJNE CHLOPAKI        1          13            7.4
# 12553                7     Prestige EC        0          13           12.6
# 12554                5          ZennoX        1          16           13.8
# 12555                2           flyys        0           4            5.2
# 12556               10  ex-Altay Espor        1          13            7.2
#
#       Second Half Score Overtime score                        competition_id  \
# 0                     0              0  3cd81a7e-ed93-43ba-be08-2a1ee7ad7237
# 1                     0              0  3cd81a7e-ed93-43ba-be08-2a1ee7ad7237
# 2                     3              0  4410aa73-9584-4500-a7ca-1504ed6da707
# 3                     8              0  4410aa73-9584-4500-a7ca-1504ed6da707
# 4                     6              4  f62c4c75-f620-40a2-bef8-0be2cb85d2d3
# ...                 ...            ...                                   ...
# 12552                 9              0  0ce757ef-9bad-4afa-bbce-58d647824222
# 12553                 5              1  bd7957b3-1114-435f-af43-22645a508cc0
# 12554                 7              4  bd7957b3-1114-435f-af43-22645a508cc0
# 12555                 2              0  bd7957b3-1114-435f-af43-22645a508cc0
# 12556                 3              0  bd7957b3-1114-435f-af43-22645a508cc0
#
#                 match_day
# 0     2025-07-30 18:40:44
# 1     2025-07-30 18:40:44
# 2     2025-08-19 18:13:11
# 3     2025-08-19 18:13:11
# 4     2025-07-16 18:37:21
# ...                   ...
# 12552 2025-08-25 20:11:48
# 12553 2025-08-25 18:11:52
# 12554 2025-08-25 18:11:52
# 12555 2025-08-25 18:13:18
# 12556 2025-08-25 18:13:18
#
# [12557 rows x 14 columns]

# %%
fact_teams_stats = fact_teams_stats.drop(columns={'Team','Team Win','Team Headshots'})
fact_teams_stats = fact_teams_stats.rename(columns={'Final Score':'final_score','Overtime score':'overtime_score','First Half Score':'first_half_score','Second Half Score':'second_half_score'})

# %%
fact_teams_stats.head(2)
# Out:
#                                  match_id match_round  \
# 0  1-74860e59-e961-4a1c-868c-55ef7d3215b8           1
# 1  1-74860e59-e961-4a1c-868c-55ef7d3215b8           1
#
#                                 team_id team_win total_rounds_played  \
# 0  30191a9c-ceb2-4da0-a146-ec375782ac45        0                  12
# 1  f8ac5861-2bb7-4dd1-8378-afa7a9257920        1                  12
#
#   first_half_score final_score second_half_score overtime_score  \
# 0                1           1                 0              0
# 1               11          11                 0              0
#
#                          competition_id           match_day
# 0  3cd81a7e-ed93-43ba-be08-2a1ee7ad7237 2025-07-30 18:40:44
# 1  3cd81a7e-ed93-43ba-be08-2a1ee7ad7237 2025-07-30 18:40:44

# %%
#correction d'un cas ou les données d'une game sont en doublons, on garde les lignes qui ont les stats les plus importantes, exemple :https://www.faceit.com/fr/cs2/room/1-e4410b46-a6ac-4037-ad35-d7f91f8bf55f/scoreboard
team_stats_sorted = fact_teams_stats.sort_values(['match_id', 'team_id', 'final_score'], ascending=[True, True, False])
fact_teams_stats = team_stats_sorted.drop_duplicates(subset=['match_id', 'team_id'], keep='first')

column_order=['match_id','match_round','team_id','competition_id','team_win','total_rounds_played','first_half_score','second_half_score','overtime_score','final_score']
fact_teams_stats = fact_teams_stats[column_order]

# %%
fact_teams_stats.columns
# Out:
# Index(['match_id', 'match_round', 'team_id', 'competition_id', 'team_win',
#        'total_rounds_played', 'first_half_score', 'second_half_score',
#        'overtime_score', 'final_score'],
#       dtype='object')

# %%
fact_teams_stats.dtypes
# Out:
# match_id               object
# match_round            object
# team_id                object
# competition_id         object
# team_win               object
# total_rounds_played    object
# first_half_score       object
# second_half_score      object
# overtime_score         object
# final_score            object
# dtype: object

# %% [markdown]
# ## Summary of tables & columns

# %%
dim_championships.columns
# Out:
# Index(['competition_id', 'organizer', 'competition_type', 'region',
#        'sub_region', 'season', 'division', 'state', 'started_at'],
#       dtype='object')

# %%
dim_teams.columns
# Out:
# Index(['team_id', 'team_nickname', 'team_name', 'team_avatar',
#        'team_faceit_url'],
#       dtype='object')

# %%
dim_players.columns
# Out:
# Index(['player_id', 'team_id', 'player_name', 'player_country',
#        'player_faceit_url', 'player_avatar'],
#       dtype='object')

# %%
dim_matches.columns
# Out:
# Index(['match_id', 'match_round', 'competition_id', 'match_day', 'format',
#        'map', 'total_rounds_played', 'winner_id', 'loser_id'],
#       dtype='object')

# %%
fact_players_stats.columns
# Out:
# Index(['match_id', 'match_round', 'player_id', 'competition_id', 'team_id',
#        'zeus_kills', 'utility_count', 'double_kills', 'flash_successes',
#        'quadro_kills', 'entry_count', 'first_kills', 'flash_count',
#        'sniper_kills', 'damage', 'utility_damage', 'assists', 'count_1v1',
#        'enemies_flashed', 'clutch_kills', 'ace', 'mvps', 'deaths',
#        'entry_wins', 'kills', 'wins_1v2', 'wins_1v1', 'pistol_kills',
#        'knife_kills', 'adr', 'count_1v2', 'triple_kills', 'headshots',
#        'match_day'],
#       dtype='object')

# %%
fact_teams_stats.columns
# Out:
# Index(['match_id', 'match_round', 'team_id', 'competition_id', 'team_win',
#        'total_rounds_played', 'first_half_score', 'second_half_score',
#        'overtime_score', 'final_score'],
#       dtype='object')

# %%
# Find IDs in fact that are missing in dim
missing_in_dim = fact_players_stats.loc[~fact_players_stats["player_id"].isin(dim_players["player_id"]), "player_id"].unique()

# Find IDs in dim that are missing in fact
missing_in_fact = dim_players.loc[~dim_players["player_id"].isin(fact_players_stats["player_id"]), "player_id"].unique()

print(f"IDs in fact but not in dim: {missing_in_dim}")
print(f"IDs in dim but not in fact: {missing_in_fact}")

# Optional: get the actual fact rows with missing IDs
fact_missing_rows = fact_players_stats[fact_players_stats["player_id"].isin(missing_in_dim)]
# Out:
# IDs in fact but not in dim: []
# IDs in dim but not in fact: []

# %% [markdown]
# ## Data ingestion on PostgreSQL DB

# %%
engine = create_engine(
    f"postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}"
)

# %%
primary_keys_map = {
    "dim_championships": ["competition_id"],
    "dim_teams": ["team_id"],
    "dim_players": ["player_id"],
    "dim_matches": ["match_id", "match_round"],
    "fact_teams_stats": ["match_id", "match_round", "team_id"],
    "fact_players_stats": ["match_id", "match_round", "player_id"]
}

def insert_new_records(df, table_name, pk_cols, chunk_size=5000):
    try:
        pk_cols_str = ', '.join(pk_cols)
        query = f"SELECT {pk_cols_str} FROM {table_name}"
        
        existing_pks_df = pd.read_sql(query, engine)

        # Normalize keys to string to avoid datatype mismatches
        for col in pk_cols:
            df[col] = df[col].astype(str)
            existing_pks_df[col] = existing_pks_df[col].astype(str)

        if len(pk_cols) == 1:
            col = pk_cols[0]
            mask = ~df[col].isin(existing_pks_df[col])
        else:
            df_keys = df[pk_cols].apply(tuple, axis=1)
            existing_keys = existing_pks_df.apply(tuple, axis=1)
            mask = ~df_keys.isin(existing_keys)
        
        new_records_df = df[mask]
        
        if not new_records_df.empty:
            new_records_df.to_sql(
                table_name,
                con=engine,
                if_exists='append',
                index=False,
                method='multi',
                chunksize=chunk_size  # <-- added chunking
            )
            print(f"Inserted {len(new_records_df)} new records into {table_name}")
        else:
            print(f"No new records to insert for {table_name}")
    except SQLAlchemyError as e:
        print(f"Database error while inserting into {table_name}: {e}")
    except Exception as e:
        print(f"Unexpected error while inserting into {table_name}: {e}")

def main():
    try:
        insert_new_records(dim_championships, "dim_championships", primary_keys_map["dim_championships"])
        insert_new_records(dim_teams, "dim_teams", primary_keys_map["dim_teams"])
        insert_new_records(dim_players, "dim_players", primary_keys_map["dim_players"])
        insert_new_records(dim_matches, "dim_matches", primary_keys_map["dim_matches"])
        insert_new_records(fact_teams_stats, "fact_teams_stats", primary_keys_map["fact_teams_stats"])
        insert_new_records(fact_players_stats, "fact_players_stats", primary_keys_map["fact_players_stats"])
    except Exception as e:
        print(f"Error in main loading process: {e}")

if __name__ == "__main__":
    main()
# Out:
# No new records to insert for dim_championships
# No new records to insert for dim_teams
# No new records to insert for dim_players
# No new records to insert for dim_matches
# No new records to insert for fact_teams_stats
# Inserted 9 new records into fact_players_stats

# %%
print(len(master_matches))
print(len(existing_match_ids))
print(len(dim_matches_matchquery))          # before merge
print(len(filtered_captain_matches_df))     # the DF you merge on
print(len(dim_matches))
# Out:
# 6907
# 5970
# 12565
# 7800
# 7800
